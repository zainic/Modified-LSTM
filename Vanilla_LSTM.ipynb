# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time as tm
import datetime

def windowed_dataset(data_series, num=5):
    """
    windowed the data
    args:
      data_series: (ndarray)
      num: (int, default:5)
    return: 
      windowed_data (ndarray)
    """
    windowed_data = []
    target_data = []
    for i in range(len(data_series) - num):
        windowed_data.append(data_series[i : i + num])
        target_data.append(data_series[i + num])
    return np.array(windowed_data), np.array(target_data)

def import_dataset(path):
    """
    Import the dataset contains data of time series
    The data of oldest time should be on top and the recent should be on bottom
    args:
      path : directory of the data file (str)
    return:
      dataframe (DataFrame)
    """
    df = pd.read_csv(path)
    return df

def split_series_and_date(df):
    """
    splitting the series and date into two different variable
    args:
      df : dataset of time series (DataFrame)
    return:
      series (DataFrame)
      time (ndarray)
    """
    time = df[df.columns[0]].to_numpy()
    df.drop(df.columns[0], axis=1, inplace=True)
    return df, time

def normalize(data_series):
    """
    Normalized the data based on each columns
    args:
      data_series: (ndarray)
    return: 
      normalized_data (ndarray), maximum (ndarray), minimum (ndarray)
    """
    maximum = np.array([])
    minimum = np.array([])
    normalized_data = []
    for col in data_series.T:
        max_col = np.max(col)
        min_col = np.min(col)
        normalized_data_col = (col - min_col) / (max_col - min_col)
        normalized_data.append(normalized_data_col)
        maximum = np.concatenate([maximum, np.array([max_col])])
        minimum = np.concatenate([minimum, np.array([min_col])])
    return np.array(normalized_data).T, maximum, minimum

def denormalize(normalized_data, maximum, minimum):
    """
    Denormalized the data based on maximum and minimum value of each column before
    args:
      normalized_data: (ndarray)
      maximum: (ndarray)
      minimum: (ndarray)
    return: 
      denormalized_data (ndarray)
    """
    normalized_data = np.array(normalized_data).T
    denormalized_data = []
    for max_col, min_col, col in zip(maximum, minimum, normalized_data):
        denormalized_data_col = (col * (max_col - min_col)) + min_col
        denormalized_data.append(denormalized_data_col)
    return np.array(denormalized_data).T
    
def initial_weights_and_biases(num_data, hidden_size, zero = False):
    """
    initial weights and biases for Vanilla LSTM method
    args:
      num_data : the size of data in one time (int)
      hidden_size : the size of hidden state (int)
    return:
      params (tuple) contains:
        W_g : weight from x_t to g
        W_i : weight from x_t to i
        W_f : weight from x_t to f
        W_o : weight from x_t to o
        W_y : weight from h_t to y
        R_g : weight from h_prev to g
        R_i : weight from h_prev to i
        R_f : weight from h_prev to f
        R_o : weight from h_prev to o
        b_g : bias of g
        b_i : bias of i
        b_f : bias of f
        b_o : bias of o
        b_y : bias of y
    """
    W_g = np.random.randn(hidden_size, num_data)
    W_i = np.random.randn(hidden_size, num_data)
    W_f = np.random.randn(hidden_size, num_data)
    W_o = np.random.randn(hidden_size, num_data)
    W_y = np.random.randn(num_data, hidden_size)
    R_g = np.random.randn(hidden_size, hidden_size)
    R_i = np.random.randn(hidden_size, hidden_size)
    R_f = np.random.randn(hidden_size, hidden_size)
    R_o = np.random.randn(hidden_size, hidden_size)
    b_g = np.random.randn(1, hidden_size)
    b_i = np.random.randn(1, hidden_size)
    b_f = np.random.randn(1, hidden_size)
    b_o = np.random.randn(1, hidden_size)
    b_y = np.random.randn(1, num_data)
    params = W_g, W_i, W_f, W_o, W_y, R_g, R_i, R_f, R_o, b_g, b_i, b_f, b_o, b_y
    if zero:
        W_g -= W_g
        W_i -= W_i
        W_f -= W_f
        W_o -= W_o
        W_y -= W_y
        R_g -= R_g
        R_i -= R_i
        R_f -= R_f
        R_o -= R_o
        b_g -= b_g
        b_i -= b_i
        b_f -= b_f
        b_o -= b_o
        b_y -= b_y
    return params

def tanh(x, derivative=False):
    """
    tanh function
    """
    f = np.tanh(x)
    if derivative:
        return 1 - (f ** 2)
    else:
        return f

def sigmoid(x, derivative=False):
    """
    sigmoid function
    """
    f = 1 / (1 + np.exp(-x))
    if derivative:
        return f * (1 - f)
    else:
        return f

def get_mean_squared_error(output, target):
    """
    get mean squared error loss value from prediction
    input must be in same dimension
    args:
      output : output from forward prediction (ndarray)
      target : target from real data (ndarray)
    return: 
      loss (float)
    """
    return (1/len(output)) * np.sum((target - output) ** 2)

def get_loss(n, output, target, loss_type = "MSE", derivative=False):
    """
    get loss value from prediction
    input must be in same dimension
    args:
      n : total amount of train data set (int)
      output : output from forward prediction (ndarray)
      target : target from real data (ndarray)
      derivative : (boolean) (default = False)
    return: 
      loss (float)
    """
    if loss_type.lower() == "mse": 
        if derivative:
            return 2 * (target - output) / n
        else:
            return np.power(target - output, 2) / n
    elif loss_type.lower() == 'mape':
        E = (target - output) / target
        if derivative:
            return (E / np.abs(E)) / n
        else:
            return np.abs(E) / n
    elif loss_type.lower() == 'mae':
        E = target - output
        if derivative:
            return (E / np.abs(E)) / n
        else:
            return np.abs(E) / n

def clip_gradient_norm(grads, max_norm = 0.5):
    """
    Clips gradients to have a maximum norm of `max_norm`.
    This is to prevent the exploding gradients problem.
    args:
      grads: contains (tuple) 
      max_norm: (float) (default = 0.5)
    return: 
      grads (ndarray) contain:
        dWg : gradient of weight from x_t to g
        dWi : gradient of weight from x_t to i
        dWf : gradient of weight from x_t to f
        dWo : gradient of weight from x_t to o
        dRg : gradient of weight from h_prev to g
        dRi : gradient of weight from h_prev to i
        dRf : gradient of weight from h_prev to f
        dRo : gradient of weight from h_prev to o
        dbg : gradient of bias of g
        dbi : gradient of bias of i
        dbf : gradient of bias of f
        dbo : gradient of bias of o
    """ 
    total_norm = 0
    
    for grad in grads:
        grad_norm = np.sum(np.power(grad, 2))
        total_norm += grad_norm
    
    total_norm = np.sqrt(total_norm)
    
    if total_norm != 0:
        clip_coef = max_norm / (total_norm)
    else:
        clip_coef = max_norm / (total_norm + 1e-8)
    
    if clip_coef < 1:
        for grad in grads:
            grad *= clip_coef
    
    return grads

def LSTM(weights, input, h_prev, c_prev):
    W_g, W_i, W_f, W_o, W_y, R_g, R_i, R_f, R_o, b_g, b_i, b_f, b_o, b_y = weights
    f_t = sigmoid(np.double(W_f @ input.T + R_f @ h_prev.T + b_f.T)).T
    i_t = sigmoid(np.double(W_i @ input.T + R_i @ h_prev.T + b_i.T)).T
    g_t = tanh(np.double(W_g @ input.T + R_g @ h_prev.T + b_g.T)).T
    c_t = i_t * g_t + f_t * c_prev
    o_t = sigmoid(np.double(W_o @ input.T + R_o @ h_prev.T + b_o.T)).T
    h_t = o_t * tanh(np.double(c_t))
    return f_t, i_t, g_t, c_t, o_t, h_t

def dense(W_y, b_y, h_t):
    W_g, W_i, W_f, W_o, W_y, R_g, R_i, R_f, R_o, b_g, b_i, b_f, b_o, b_y = weights
    y = sigmoid(np.double(W_y @ h_t.T + b_y.T)).T
    return y

def forward(weights, inputs, h_prev, c_prev):
    W_g, W_i, W_f, W_o, W_y, R_g, R_i, R_f, R_o, b_g, b_i, b_f, b_o, b_y = weights

    for t, input in enumerate(inputs):
        input = np.reshape(input, (1, len(input)))
        f_t, i_t, g_t, c_t, o_t, h_t = LSTM(weights, input, h_prev, c_prev)
        if t < len(inputs):
            c_prev = np.copy(c_t)
            h_prev = np.copy(h_t)

    y = dense(W_y, b_y, h_t)
    outputs_params = (input, c_prev, h_prev, g_t, i_t, f_t, c_t, o_t, h_t, y)

    return outputs_params

def backward(n, weights, t, outputs_params):
    W_g, W_i, W_f, W_o, W_y, R_g, R_i, R_f, R_o, b_g, b_i, b_f, b_o, b_y = weights
    
    dWg = np.zeros_like(W_g)
    dRg = np.zeros_like(R_g)
    dbg = np.zeros_like(b_g)

    dWi = np.zeros_like(W_i)
    dRi = np.zeros_like(R_i)
    dbi = np.zeros_like(b_i)
    
    dWf = np.zeros_like(W_f)
    dRf = np.zeros_like(R_f)
    dbf = np.zeros_like(b_f)

    dWo = np.zeros_like(W_o)
    dRo = np.zeros_like(R_o)
    dbo = np.zeros_like(b_o)

    dWy = np.zeros_like(W_y)
    dby = np.zeros_like(b_y)

    input, c_prev, h_prev, g_t, i_t, f_t, c_t, o_t, h_t, y = outputs_params

    loss_mse = get_loss(n, np.copy(t), np.copy(y), loss_type = "mse")
    loss_mae = get_loss(n, np.copy(t), np.copy(y), loss_type = "mae")
    loss_mape = get_loss(n, np.copy(t), np.copy(y), loss_type = "mape")

    dE = get_loss(n, np.copy(t), np.copy(y), loss_type = "mse", derivative=True)

    dy = np.reshape(dE, (len(y[0]), 1)) * sigmoid(np.double(W_y @ h_t.T + b_y.T), derivative = True)
    dWy += dy @ h_t
    dby += dy.T

    dh = (dy.T @ W_y).T

    do = sigmoid(np.double(W_o @ input.T + R_o @ h_prev.T + b_o.T), derivative = True)
    dWo += dh * (do @ input) * tanh(c_t).T
    dRo += dh * (do @ h_prev) * tanh(c_t).T
    dbo += (dh * do * tanh(c_t).T).T

    di = sigmoid(np.double(W_i @ input.T + R_i @ h_prev.T + b_i.T), derivative = True)
    dWi += dh * o_t.T * tanh(c_t).T * (di @ input)
    dRi += dh * o_t.T * tanh(c_t).T * (di @ h_prev)
    dbi += (dh * o_t.T * tanh(c_t).T * di).T

    df = sigmoid(np.double(W_f @ input.T + R_f @ h_prev.T + b_f.T), derivative = True)
    dWf += dh * o_t.T * tanh(c_t).T * (df @ input) * c_prev.T
    dRf += dh * o_t.T * tanh(c_t).T * (df @ h_prev) * c_prev.T
    dbf += (dh * o_t.T * tanh(c_t).T * df).T

    dg = tanh(np.double(W_g @ input.T + R_g @ h_prev.T) ,derivative=True)
    dWg += dh * (o_t * tanh(np.double(c_t), derivative=True)).T * i_t.T * (dg @ input)
    dRg += dh * (o_t * tanh(np.double(c_t), derivative=True)).T * i_t.T * (dg @ h_prev)
    dbg += (dh * (o_t * tanh(np.double(c_t), derivative=True)).T * i_t.T).T

    grads = dWg, dWi, dWf, dWo, dWy, dRg, dRi, dRf, dRo, dbg, dbi, dbf, dbo, dby

    loss = (loss_mse, loss_mae, loss_mape)

    return grads, loss

def RMSprop(weights, v_weights, grads, learning_rate=1e-3, beta = 0.9):
    """
    RMSprop as optimizers for update the weights
    args:
      weights : contains weight and bias (tuple) 
      v_weights : moment of weight and bias (tuple)
      grads : contains gradient of weight and bias (tuple)
      learning_rate : (float) (default = 1e-3)
      beta : (float) (default = 0.9)
    return: 
      weights : contains weight and bias (tuple) 
      v_weights : moment of weight and bias (tuple)
    """
    for weight, v_weight, grad in zip(weights, v_weights, grads):
        v_weight *= beta
        v_weight += (1 - beta) * np.power(grad, 2)
        weight -= learning_rate * (grad / (np.sqrt(v_weight) + 1e-6)) 

    return weights, v_weights

# %%
from google.colab import drive
drive.mount('/content/drive')

df = pd.read_csv("drive/MyDrive/Dataset/AAPL.csv")
time = df[df.columns[0]]
df.drop(df.columns[0], axis=1, inplace=True)
time = time.to_numpy()
series = df.to_numpy()

series, maximum, minimum = normalize(series)
length_time = 21
series_set, target_set = windowed_dataset(series, num = length_time)
num_data = len(series_set)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
split_time = int(0.8 * num_data)

train_set = series_set[:split_time]
train_label = target_set[:split_time]
test_set = series_set[split_time:]
test_label = target_set[split_time:]

num_train = len(train_set)
num_test = len(test_set)

hidden_size = 5

v_weights = initial_weights_and_biases(len(series[0]), hidden_size, zero = True)
weights = initial_weights_and_biases(len(series[0]), hidden_size)

epochs = 30
learning_rate = 0.001

for i in range(epochs):
    
    train_loss_mse = 0
    train_loss_mae = 0
    train_loss_mape = 0
    test_loss_mse = 0
    test_loss_mae = 0
    test_loss_mape = 0

    st = tm.time_ns()

    for train, label in zip(train_set, train_label):
        h_prev = np.zeros([1, hidden_size])
        c_prev = np.zeros([1, hidden_size])

        outputs_params = forward(weights, train, h_prev, c_prev)
        grads, loss = backward(num_train, weights, label, outputs_params)

        weights, v_weights = RMSprop(weights, v_weights, grads, learning_rate = learning_rate)

        train_loss_mse += loss[0]
        train_loss_mae += loss[1]
        train_loss_mape += loss[2]

    et = tm.time_ns()

    for test, label in zip(test_set, test_label):
        h_prev = np.zeros([1, hidden_size])
        c_prev = np.zeros([1, hidden_size])

        outputs_params = forward(weights, test, h_prev, c_prev)

        _, loss = backward(num_test, weights, label, outputs_params)

        test_loss_mse += loss[0]
        test_loss_mae += loss[1]
        test_loss_mape += loss[2]

    print(f"epoch {i+1} : time elapse {round((et-st) * 1e-9, 3)}")
    print(f"train loss (mse, mae, mape) : ({round(np.mean(train_loss_mse),8)}, {round(np.mean(train_loss_mae),8)}, {round(np.mean(train_loss_mape),8)})")
    print(f"test loss (mse, mae, mape) : ({round(np.mean(test_loss_mse),8)}, {round(np.mean(test_loss_mae),8)}, {round(np.mean(test_loss_mape),8)})\n")
# Out:
# epoch 1 : time elapse 1.26
# train loss (mse, mae, mape) : (0.07345979, 0.20873018, 0.46124661)
# test loss (mse, mae, mape) : (0.03809242, 0.17617743, 0.32343338)
#
# epoch 2 : time elapse 1.257
# train loss (mse, mae, mape) : (0.06730802, 0.19706578, 0.45870711)
# test loss (mse, mae, mape) : (0.03267832, 0.16107542, 0.29991874)
#
# epoch 3 : time elapse 1.244
# train loss (mse, mae, mape) : (0.06335255, 0.18726787, 0.45445891)
# test loss (mse, mae, mape) : (0.02892073, 0.15059148, 0.2814816)
#
# epoch 4 : time elapse 1.26
# train loss (mse, mae, mape) : (0.06040074, 0.1808344, 0.45150078)
# test loss (mse, mae, mape) : (0.02625511, 0.14290852, 0.26778695)
#
# epoch 5 : time elapse 1.273
# train loss (mse, mae, mape) : (0.05852611, 0.17690933, 0.44867232)
# test loss (mse, mae, mape) : (0.02442407, 0.13747583, 0.25812045)
#
# epoch 6 : time elapse 1.259
# train loss (mse, mae, mape) : (0.05613959, 0.17105267, 0.43794451)
# test loss (mse, mae, mape) : (0.02243394, 0.13128646, 0.24715442)
#
# epoch 7 : time elapse 1.265
# train loss (mse, mae, mape) : (0.04882929, 0.15273377, 0.39939521)
# test loss (mse, mae, mape) : (0.01908201, 0.11978053, 0.22689502)
#
# epoch 8 : time elapse 1.348
# train loss (mse, mae, mape) : (0.0290477, 0.10951716, 0.34374279)
# test loss (mse, mae, mape) : (0.0132617, 0.09773612, 0.18905526)
#
# epoch 9 : time elapse 1.231
# train loss (mse, mae, mape) : (0.00932977, 0.06163563, 0.29167176)
# test loss (mse, mae, mape) : (0.01048721, 0.08549076, 0.17505028)
#
# epoch 10 : time elapse 1.232
# train loss (mse, mae, mape) : (0.00551816, 0.04517106, 0.24640276)
# test loss (mse, mae, mape) : (0.00961457, 0.08155292, 0.16920747)
#
# epoch 11 : time elapse 1.231
# train loss (mse, mae, mape) : (0.00477372, 0.0408325, 0.22285555)
# test loss (mse, mae, mape) : (0.00907808, 0.07904067, 0.16505689)
#
# epoch 12 : time elapse 1.251
# train loss (mse, mae, mape) : (0.00430321, 0.03844259, 0.20139809)
# test loss (mse, mae, mape) : (0.00864806, 0.07687907, 0.16185844)
#
# epoch 13 : time elapse 1.246
# train loss (mse, mae, mape) : (0.0040545, 0.03761087, 0.19372055)
# test loss (mse, mae, mape) : (0.00811026, 0.07397145, 0.15861216)
#
# epoch 14 : time elapse 1.243
# train loss (mse, mae, mape) : (0.00385717, 0.03719397, 0.19123148)
# test loss (mse, mae, mape) : (0.00761571, 0.07117778, 0.15672562)
#
# epoch 15 : time elapse 1.26
# train loss (mse, mae, mape) : (0.00371925, 0.03691251, 0.19061719)
# test loss (mse, mae, mape) : (0.0072287, 0.06892121, 0.15636384)
#
# epoch 16 : time elapse 1.249
# train loss (mse, mae, mape) : (0.0036234, 0.0366788, 0.19059941)
# test loss (mse, mae, mape) : (0.00695381, 0.06726829, 0.15676586)
#
# epoch 17 : time elapse 1.233
# train loss (mse, mae, mape) : (0.00356283, 0.03647642, 0.19059836)
# test loss (mse, mae, mape) : (0.00674578, 0.06602818, 0.15753021)
#
# epoch 18 : time elapse 1.25
# train loss (mse, mae, mape) : (0.00352344, 0.03627499, 0.19030234)
# test loss (mse, mae, mape) : (0.00656867, 0.06500909, 0.15829051)
#
# epoch 19 : time elapse 1.25
# train loss (mse, mae, mape) : (0.0034938, 0.03603004, 0.189631)
# test loss (mse, mae, mape) : (0.00640355, 0.0640741, 0.15872964)
#
# epoch 20 : time elapse 1.254
# train loss (mse, mae, mape) : (0.00346756, 0.03574322, 0.18863055)
# test loss (mse, mae, mape) : (0.00624205, 0.06317588, 0.15887705)
#
# epoch 21 : time elapse 1.257
# train loss (mse, mae, mape) : (0.00344184, 0.03544327, 0.18741373)
# test loss (mse, mae, mape) : (0.00608191, 0.06229123, 0.15880346)
#
# epoch 22 : time elapse 1.245
# train loss (mse, mae, mape) : (0.00341581, 0.0351292, 0.18603833)
# test loss (mse, mae, mape) : (0.00592387, 0.06140791, 0.15858548)
#
# epoch 23 : time elapse 1.231
# train loss (mse, mae, mape) : (0.00338952, 0.03481071, 0.1846123)
# test loss (mse, mae, mape) : (0.0057697, 0.06053901, 0.15833809)
#
# epoch 24 : time elapse 1.226
# train loss (mse, mae, mape) : (0.00336327, 0.03450259, 0.18319358)
# test loss (mse, mae, mape) : (0.00562117, 0.05970051, 0.15816951)
#
# epoch 25 : time elapse 1.237
# train loss (mse, mae, mape) : (0.00333735, 0.03420054, 0.18179713)
# test loss (mse, mae, mape) : (0.00547954, 0.05888639, 0.15807171)
#
# epoch 26 : time elapse 1.247
# train loss (mse, mae, mape) : (0.00331194, 0.03390428, 0.18041994)
# test loss (mse, mae, mape) : (0.00534553, 0.05810577, 0.1580873)
#
# epoch 27 : time elapse 1.218
# train loss (mse, mae, mape) : (0.00328716, 0.03361628, 0.17908495)
# test loss (mse, mae, mape) : (0.00521934, 0.05737062, 0.15821381)
#
# epoch 28 : time elapse 1.26
# train loss (mse, mae, mape) : (0.00326308, 0.03334338, 0.17781591)
# test loss (mse, mae, mape) : (0.00510081, 0.05667212, 0.15844178)
#
# epoch 29 : time elapse 1.225
# train loss (mse, mae, mape) : (0.0032398, 0.03308244, 0.17661387)
# test loss (mse, mae, mape) : (0.00498962, 0.05600655, 0.15876723)
#
# epoch 30 : time elapse 1.229
# train loss (mse, mae, mape) : (0.00321739, 0.03283223, 0.17547914)
# test loss (mse, mae, mape) : (0.00488534, 0.05536668, 0.15917999)

# %%
import json

split_time = int(0.8 * num_data)

train_set = series_set[:split_time]
train_label = target_set[:split_time]
test_set = series_set[split_time:]
test_label = target_set[split_time:]

num_train = len(train_set)
num_test = len(test_set)

hidden_size = 25
epochs = 30
learning_rate = 0.001
lib_weights = {}

for trial in range(30):
    print(f"Trial Number - {trial+1}")

    v_weights = initial_weights_and_biases(len(series[0]), hidden_size, zero = True)
    weights = initial_weights_and_biases(len(series[0]), hidden_size)

    total_time = 0

    for i in range(epochs):
        
        train_loss_mse = 0
        train_loss_mae = 0
        train_loss_mape = 0
        test_loss_mse = 0
        test_loss_mae = 0
        test_loss_mape = 0

        st = tm.time_ns()

        for train, label in zip(train_set, train_label):
            h_prev = np.zeros([1, hidden_size])
            c_prev = np.zeros([1, hidden_size])

            outputs_params = forward(weights, train, h_prev, c_prev)
            grads, loss = backward(num_train, weights, label, outputs_params)

            weights, v_weights = RMSprop(weights, v_weights, grads, learning_rate = learning_rate)

            train_loss_mse += loss[0]
            train_loss_mae += loss[1]
            train_loss_mape += loss[2]

        et = tm.time_ns()

        total_time += (et - st) * 1e-9

        for test, label in zip(test_set, test_label):
            h_prev = np.zeros([1, hidden_size])
            c_prev = np.zeros([1, hidden_size])

            outputs_params = forward(weights, test, h_prev, c_prev)

            _, loss = backward(num_test, weights, label, outputs_params)

            test_loss_mse += loss[0]
            test_loss_mae += loss[1]
            test_loss_mape += loss[2]

        print(f"epoch {i+1} : time elapse {round((et-st) * 1e-9, 3)}")
        print(f"train loss (mse, mae, mape) : ({round(np.mean(train_loss_mse),8)}, {round(np.mean(train_loss_mae),8)}, {round(np.mean(train_loss_mape),8)})")
        print(f"test loss (mse, mae, mape) : ({round(np.mean(test_loss_mse),8)}, {round(np.mean(test_loss_mae),8)}, {round(np.mean(test_loss_mape),8)})\n")

    result = {
        "weights" : weights,
        "train_mse" : train_loss_mse,
        "train_mae" : train_loss_mae,
        "train_mape" : train_loss_mape,
        "test_mse" : test_loss_mse,
        "test_mae" : test_loss_mae,
        "test_mape" : test_loss_mape,
        "total_time" : total_time
    }
    
    lib_weights[trial+1] = result
# Out:
# Trial Number - 1
# epoch 1 : time elapse 1.324
# train loss (mse, mae, mape) : (0.03522157, 0.11205764, 0.33456605)
# test loss (mse, mae, mape) : (0.01055667, 0.08199239, 0.20505758)
#
# epoch 2 : time elapse 1.339
# train loss (mse, mae, mape) : (0.0292063, 0.09038482, 0.37502148)
# test loss (mse, mae, mape) : (0.00743575, 0.07124282, 0.19538576)
#
# epoch 3 : time elapse 1.361
# train loss (mse, mae, mape) : (0.01324122, 0.06467075, 0.28872654)
# test loss (mse, mae, mape) : (0.00750163, 0.07244641, 0.18876155)
#
# epoch 4 : time elapse 1.336
# train loss (mse, mae, mape) : (0.01041093, 0.05876212, 0.27978794)
# test loss (mse, mae, mape) : (0.00741704, 0.0723282, 0.18024588)
#
# epoch 5 : time elapse 1.362
# train loss (mse, mae, mape) : (0.00898185, 0.05627217, 0.28082293)
# test loss (mse, mae, mape) : (0.00743597, 0.0723615, 0.17494655)
#
# epoch 6 : time elapse 1.347
# train loss (mse, mae, mape) : (0.00644425, 0.04908675, 0.24865522)
# test loss (mse, mae, mape) : (0.00666124, 0.06843587, 0.16753401)
#
# epoch 7 : time elapse 1.33
# train loss (mse, mae, mape) : (0.01027791, 0.05116954, 0.24830945)
# test loss (mse, mae, mape) : (0.00672882, 0.06879723, 0.16945871)
#
# epoch 8 : time elapse 1.344
# train loss (mse, mae, mape) : (0.00456704, 0.03854676, 0.20464616)
# test loss (mse, mae, mape) : (0.0063627, 0.06668966, 0.15992652)
#
# epoch 9 : time elapse 1.336
# train loss (mse, mae, mape) : (0.00456278, 0.03806111, 0.19928505)
# test loss (mse, mae, mape) : (0.00594876, 0.06408458, 0.15006545)
#
# epoch 10 : time elapse 1.316
# train loss (mse, mae, mape) : (0.00475282, 0.0395326, 0.20256189)
# test loss (mse, mae, mape) : (0.00546212, 0.06083829, 0.13995327)
#
# epoch 11 : time elapse 1.355
# train loss (mse, mae, mape) : (0.00501074, 0.0414134, 0.20578301)
# test loss (mse, mae, mape) : (0.00477621, 0.05633491, 0.13072346)
#
# epoch 12 : time elapse 1.331
# train loss (mse, mae, mape) : (0.00540368, 0.04318318, 0.21393938)
# test loss (mse, mae, mape) : (0.00348471, 0.04602974, 0.13259729)
#
# epoch 13 : time elapse 1.343
# train loss (mse, mae, mape) : (0.00689922, 0.04711032, 0.22252074)
# test loss (mse, mae, mape) : (0.0035364, 0.04482286, 0.17601174)
#
# epoch 14 : time elapse 1.325
# train loss (mse, mae, mape) : (0.00734895, 0.04789824, 0.21828614)
# test loss (mse, mae, mape) : (0.00496415, 0.05371711, 0.23911402)
#
# epoch 15 : time elapse 1.346
# train loss (mse, mae, mape) : (0.00783121, 0.04914694, 0.21802956)
# test loss (mse, mae, mape) : (0.00535863, 0.05615865, 0.20081001)
#
# epoch 16 : time elapse 1.327
# train loss (mse, mae, mape) : (0.00969781, 0.06257304, 0.24082724)
# test loss (mse, mae, mape) : (0.00498797, 0.05682417, 0.13466754)
#
# epoch 17 : time elapse 1.336
# train loss (mse, mae, mape) : (0.00517602, 0.0418364, 0.19566698)
# test loss (mse, mae, mape) : (0.00911891, 0.07274685, 0.15868803)
#
# epoch 18 : time elapse 1.339
# train loss (mse, mae, mape) : (0.00403221, 0.03525962, 0.1744608)
# test loss (mse, mae, mape) : (0.00987212, 0.0750301, 0.16279167)
#
# epoch 19 : time elapse 1.327
# train loss (mse, mae, mape) : (0.00366559, 0.03289685, 0.16592164)
# test loss (mse, mae, mape) : (0.0106119, 0.07688946, 0.16508188)
#
# epoch 20 : time elapse 1.327
# train loss (mse, mae, mape) : (0.00343744, 0.03144359, 0.16070681)
# test loss (mse, mae, mape) : (0.01082301, 0.07730593, 0.16564205)
#
# epoch 21 : time elapse 1.335
# train loss (mse, mae, mape) : (0.00328285, 0.03054402, 0.15760494)
# test loss (mse, mae, mape) : (0.01073105, 0.07667378, 0.16412766)
#
# epoch 22 : time elapse 1.331
# train loss (mse, mae, mape) : (0.00314762, 0.02995862, 0.15558234)
# test loss (mse, mae, mape) : (0.01087764, 0.07692244, 0.16493453)
#
# epoch 23 : time elapse 1.349
# train loss (mse, mae, mape) : (0.00308217, 0.02960299, 0.15459122)
# test loss (mse, mae, mape) : (0.01096884, 0.07678041, 0.16452285)
#
# epoch 24 : time elapse 1.366
# train loss (mse, mae, mape) : (0.00300926, 0.02942245, 0.15356251)
# test loss (mse, mae, mape) : (0.01060507, 0.07523568, 0.16264187)
#
# epoch 25 : time elapse 1.324
# train loss (mse, mae, mape) : (0.00295873, 0.02923441, 0.15348286)
# test loss (mse, mae, mape) : (0.00940512, 0.07119452, 0.15807058)
#
# epoch 26 : time elapse 1.333
# train loss (mse, mae, mape) : (0.0029211, 0.02923363, 0.15435018)
# test loss (mse, mae, mape) : (0.0080112, 0.06533999, 0.14804368)
#
# epoch 27 : time elapse 1.335
# train loss (mse, mae, mape) : (0.00285242, 0.02915533, 0.15543534)
# test loss (mse, mae, mape) : (0.00610667, 0.05743078, 0.1381206)
#
# epoch 28 : time elapse 1.336
# train loss (mse, mae, mape) : (0.00286759, 0.0295608, 0.15753737)
# test loss (mse, mae, mape) : (0.00464266, 0.05047962, 0.13808711)
#
# epoch 29 : time elapse 1.326
# train loss (mse, mae, mape) : (0.00286016, 0.02958139, 0.15845991)
# test loss (mse, mae, mape) : (0.00381395, 0.04708738, 0.14291104)
#
# epoch 30 : time elapse 1.347
# train loss (mse, mae, mape) : (0.0028616, 0.02954429, 0.15901185)
# test loss (mse, mae, mape) : (0.00349274, 0.04621615, 0.14987364)
#
# Trial Number - 2
# epoch 1 : time elapse 1.347
# train loss (mse, mae, mape) : (0.06496603, 0.15409833, 0.38958278)
# test loss (mse, mae, mape) : (0.01352682, 0.09479746, 0.23388081)
#
# epoch 2 : time elapse 1.327
# train loss (mse, mae, mape) : (0.01992308, 0.08202198, 0.31162911)
# test loss (mse, mae, mape) : (0.00835908, 0.07509518, 0.20602248)
#
# epoch 3 : time elapse 1.335
# train loss (mse, mae, mape) : (0.00838945, 0.05455826, 0.25136785)
# test loss (mse, mae, mape) : (0.00832282, 0.075349, 0.19858769)
#
# epoch 4 : time elapse 1.338
# train loss (mse, mae, mape) : (0.00498197, 0.04224781, 0.21532673)
# test loss (mse, mae, mape) : (0.00861583, 0.07683516, 0.19992176)
#
# epoch 5 : time elapse 1.326
# train loss (mse, mae, mape) : (0.00401535, 0.03804232, 0.19819553)
# test loss (mse, mae, mape) : (0.00857518, 0.07703354, 0.2002741)
#
# epoch 6 : time elapse 1.341
# train loss (mse, mae, mape) : (0.00357528, 0.03552034, 0.18798496)
# test loss (mse, mae, mape) : (0.00858829, 0.07738819, 0.2015393)
#
# epoch 7 : time elapse 1.339
# train loss (mse, mae, mape) : (0.00335664, 0.03408717, 0.1814292)
# test loss (mse, mae, mape) : (0.00845616, 0.07699875, 0.20117437)
#
# epoch 8 : time elapse 1.327
# train loss (mse, mae, mape) : (0.00317141, 0.03292481, 0.17570101)
# test loss (mse, mae, mape) : (0.00844917, 0.07712163, 0.20040355)
#
# epoch 9 : time elapse 1.341
# train loss (mse, mae, mape) : (0.00305844, 0.03216248, 0.17155087)
# test loss (mse, mae, mape) : (0.0084612, 0.07726394, 0.20044835)
#
# epoch 10 : time elapse 1.332
# train loss (mse, mae, mape) : (0.00296791, 0.03140051, 0.16775874)
# test loss (mse, mae, mape) : (0.00826738, 0.07630077, 0.20004352)
#
# epoch 11 : time elapse 1.342
# train loss (mse, mae, mape) : (0.0029302, 0.03061604, 0.16403578)
# test loss (mse, mae, mape) : (0.00782676, 0.07393681, 0.1966808)
#
# epoch 12 : time elapse 1.332
# train loss (mse, mae, mape) : (0.00293538, 0.03017691, 0.16179549)
# test loss (mse, mae, mape) : (0.00723071, 0.07056351, 0.19115341)
#
# epoch 13 : time elapse 1.326
# train loss (mse, mae, mape) : (0.00292865, 0.02970885, 0.15921877)
# test loss (mse, mae, mape) : (0.00655169, 0.06638647, 0.17871036)
#
# epoch 14 : time elapse 1.355
# train loss (mse, mae, mape) : (0.00297565, 0.02960911, 0.15896617)
# test loss (mse, mae, mape) : (0.00595047, 0.06255587, 0.1678937)
#
# epoch 15 : time elapse 1.336
# train loss (mse, mae, mape) : (0.00299402, 0.02972279, 0.15849341)
# test loss (mse, mae, mape) : (0.0056271, 0.06019178, 0.16189561)
#
# epoch 16 : time elapse 1.328
# train loss (mse, mae, mape) : (0.00301693, 0.02979755, 0.15798233)
# test loss (mse, mae, mape) : (0.00542288, 0.05858734, 0.15108253)
#
# epoch 17 : time elapse 1.334
# train loss (mse, mae, mape) : (0.00308764, 0.02995498, 0.15849087)
# test loss (mse, mae, mape) : (0.00532159, 0.05800161, 0.14265383)
#
# epoch 18 : time elapse 1.322
# train loss (mse, mae, mape) : (0.00309096, 0.03000581, 0.15782526)
# test loss (mse, mae, mape) : (0.00546092, 0.05894925, 0.14280856)
#
# epoch 19 : time elapse 1.333
# train loss (mse, mae, mape) : (0.0031363, 0.03007496, 0.15906201)
# test loss (mse, mae, mape) : (0.00530772, 0.0581791, 0.14008015)
#
# epoch 20 : time elapse 1.35
# train loss (mse, mae, mape) : (0.0031223, 0.03007271, 0.16095261)
# test loss (mse, mae, mape) : (0.00526505, 0.05772738, 0.13851816)
#
# epoch 21 : time elapse 1.35
# train loss (mse, mae, mape) : (0.00306548, 0.02985966, 0.16089135)
# test loss (mse, mae, mape) : (0.00532784, 0.05771327, 0.14027714)
#
# epoch 22 : time elapse 1.344
# train loss (mse, mae, mape) : (0.00302356, 0.02950245, 0.16006564)
# test loss (mse, mae, mape) : (0.00539741, 0.05787341, 0.14319072)
#
# epoch 23 : time elapse 1.345
# train loss (mse, mae, mape) : (0.00303631, 0.02968574, 0.16045984)
# test loss (mse, mae, mape) : (0.00562577, 0.05878113, 0.14879439)
#
# epoch 24 : time elapse 1.33
# train loss (mse, mae, mape) : (0.0031848, 0.03036046, 0.16153715)
# test loss (mse, mae, mape) : (0.00610061, 0.06190015, 0.17326281)
#
# epoch 25 : time elapse 1.342
# train loss (mse, mae, mape) : (0.00315298, 0.03014741, 0.16209476)
# test loss (mse, mae, mape) : (0.00689823, 0.06514308, 0.18407165)
#
# epoch 26 : time elapse 1.351
# train loss (mse, mae, mape) : (0.00306579, 0.02980399, 0.16168797)
# test loss (mse, mae, mape) : (0.00753869, 0.06783834, 0.19074501)
#
# epoch 27 : time elapse 1.334
# train loss (mse, mae, mape) : (0.00296667, 0.02929757, 0.16116052)
# test loss (mse, mae, mape) : (0.00906745, 0.07350515, 0.19736007)
#
# epoch 28 : time elapse 1.338
# train loss (mse, mae, mape) : (0.00302749, 0.02950956, 0.16377124)
# test loss (mse, mae, mape) : (0.01408183, 0.09372425, 0.20571291)
#
# epoch 29 : time elapse 1.326
# train loss (mse, mae, mape) : (0.0030479, 0.02965501, 0.16024843)
# test loss (mse, mae, mape) : (0.01309951, 0.09135115, 0.19043138)
#
# epoch 30 : time elapse 1.343
# train loss (mse, mae, mape) : (0.00309142, 0.03004686, 0.15868605)
# test loss (mse, mae, mape) : (0.00872173, 0.07563055, 0.1574698)
#
# Trial Number - 3
# epoch 1 : time elapse 1.351
# train loss (mse, mae, mape) : (0.06089958, 0.1410539, 0.3971264)
# test loss (mse, mae, mape) : (0.0080137, 0.07577425, 0.16875587)
#
# epoch 2 : time elapse 1.333
# train loss (mse, mae, mape) : (0.017387, 0.07717327, 0.35971216)
# test loss (mse, mae, mape) : (0.09287742, 0.20306931, 0.73085225)
#
# epoch 3 : time elapse 1.343
# train loss (mse, mae, mape) : (0.01068876, 0.06420005, 0.28460501)
# test loss (mse, mae, mape) : (0.02410249, 0.12097297, 0.24055444)
#
# epoch 4 : time elapse 1.34
# train loss (mse, mae, mape) : (0.00714355, 0.05000529, 0.2311526)
# test loss (mse, mae, mape) : (0.0073109, 0.07098654, 0.15605062)
#
# epoch 5 : time elapse 1.333
# train loss (mse, mae, mape) : (0.00478636, 0.04286581, 0.21341968)
# test loss (mse, mae, mape) : (0.00702524, 0.06938178, 0.15444888)
#
# epoch 6 : time elapse 1.361
# train loss (mse, mae, mape) : (0.00482244, 0.04426435, 0.21349066)
# test loss (mse, mae, mape) : (0.00688469, 0.0680319, 0.15308347)
#
# epoch 7 : time elapse 1.332
# train loss (mse, mae, mape) : (0.00498172, 0.0452774, 0.2167321)
# test loss (mse, mae, mape) : (0.00663345, 0.06600353, 0.15089753)
#
# epoch 8 : time elapse 1.33
# train loss (mse, mae, mape) : (0.00495456, 0.04512155, 0.22006969)
# test loss (mse, mae, mape) : (0.00654986, 0.06487163, 0.15004136)
#
# epoch 9 : time elapse 1.34
# train loss (mse, mae, mape) : (0.00461145, 0.04338606, 0.21532544)
# test loss (mse, mae, mape) : (0.00690037, 0.06687338, 0.15482205)
#
# epoch 10 : time elapse 1.323
# train loss (mse, mae, mape) : (0.00450177, 0.0430655, 0.20845678)
# test loss (mse, mae, mape) : (0.00726558, 0.06931389, 0.16119861)
#
# epoch 11 : time elapse 1.327
# train loss (mse, mae, mape) : (0.0043883, 0.04267509, 0.20177499)
# test loss (mse, mae, mape) : (0.00747208, 0.07083102, 0.16394439)
#
# epoch 12 : time elapse 1.331
# train loss (mse, mae, mape) : (0.00458409, 0.04377116, 0.20034114)
# test loss (mse, mae, mape) : (0.00809468, 0.07421835, 0.16890451)
#
# epoch 13 : time elapse 1.336
# train loss (mse, mae, mape) : (0.0046402, 0.04359093, 0.1993612)
# test loss (mse, mae, mape) : (0.00880366, 0.07776885, 0.17282007)
#
# epoch 14 : time elapse 1.335
# train loss (mse, mae, mape) : (0.00441144, 0.04143264, 0.19509365)
# test loss (mse, mae, mape) : (0.0090273, 0.07929306, 0.17594452)
#
# epoch 15 : time elapse 1.329
# train loss (mse, mae, mape) : (0.00391778, 0.03824613, 0.1845281)
# test loss (mse, mae, mape) : (0.00826624, 0.07617868, 0.17476147)
#
# epoch 16 : time elapse 1.352
# train loss (mse, mae, mape) : (0.00363724, 0.03572411, 0.17706521)
# test loss (mse, mae, mape) : (0.0077098, 0.07290648, 0.17447938)
#
# epoch 17 : time elapse 1.334
# train loss (mse, mae, mape) : (0.00346577, 0.03479056, 0.1742235)
# test loss (mse, mae, mape) : (0.00732409, 0.07047467, 0.17531091)
#
# epoch 18 : time elapse 1.339
# train loss (mse, mae, mape) : (0.00343622, 0.03418846, 0.17234733)
# test loss (mse, mae, mape) : (0.007419, 0.07125508, 0.17559733)
#
# epoch 19 : time elapse 1.331
# train loss (mse, mae, mape) : (0.00347832, 0.03437227, 0.17284026)
# test loss (mse, mae, mape) : (0.0072357, 0.07037041, 0.17772752)
#
# epoch 20 : time elapse 1.352
# train loss (mse, mae, mape) : (0.00339632, 0.0338093, 0.17224571)
# test loss (mse, mae, mape) : (0.00705612, 0.06935957, 0.17624277)
#
# epoch 21 : time elapse 1.335
# train loss (mse, mae, mape) : (0.00327073, 0.03335702, 0.17154524)
# test loss (mse, mae, mape) : (0.00688927, 0.06828608, 0.17298046)
#
# epoch 22 : time elapse 1.343
# train loss (mse, mae, mape) : (0.00327092, 0.03314676, 0.17245542)
# test loss (mse, mae, mape) : (0.00681015, 0.06779701, 0.16828637)
#
# epoch 23 : time elapse 1.319
# train loss (mse, mae, mape) : (0.00326072, 0.03326295, 0.17249048)
# test loss (mse, mae, mape) : (0.00690093, 0.06834513, 0.16153188)
#
# epoch 24 : time elapse 1.33
# train loss (mse, mae, mape) : (0.00334525, 0.03391463, 0.17483089)
# test loss (mse, mae, mape) : (0.00687923, 0.06828681, 0.15706339)
#
# epoch 25 : time elapse 1.342
# train loss (mse, mae, mape) : (0.00339859, 0.03423213, 0.17633575)
# test loss (mse, mae, mape) : (0.00687349, 0.06837402, 0.15398022)
#
# epoch 26 : time elapse 1.325
# train loss (mse, mae, mape) : (0.00346968, 0.03482692, 0.17809211)
# test loss (mse, mae, mape) : (0.00691035, 0.06876586, 0.15110811)
#
# epoch 27 : time elapse 1.339
# train loss (mse, mae, mape) : (0.00346554, 0.03488369, 0.17747705)
# test loss (mse, mae, mape) : (0.00714481, 0.07007123, 0.15004866)
#
# epoch 28 : time elapse 1.323
# train loss (mse, mae, mape) : (0.00344167, 0.03461043, 0.17591387)
# test loss (mse, mae, mape) : (0.00725438, 0.07089265, 0.1495968)
#
# epoch 29 : time elapse 1.356
# train loss (mse, mae, mape) : (0.00350315, 0.03502657, 0.17755173)
# test loss (mse, mae, mape) : (0.00693448, 0.0694142, 0.14693404)
#
# epoch 30 : time elapse 1.354
# train loss (mse, mae, mape) : (0.00356462, 0.03533304, 0.17853106)
# test loss (mse, mae, mape) : (0.00655741, 0.06757049, 0.14398748)
#
# Trial Number - 4
# epoch 1 : time elapse 1.327
# train loss (mse, mae, mape) : (0.0216997, 0.08575224, 0.33486387)
# test loss (mse, mae, mape) : (0.00928051, 0.08013349, 0.16446085)
#
# epoch 2 : time elapse 1.331
# train loss (mse, mae, mape) : (0.03041642, 0.10935173, 0.51927742)
# test loss (mse, mae, mape) : (0.00837765, 0.07783848, 0.15715514)
#
# epoch 3 : time elapse 1.352
# train loss (mse, mae, mape) : (0.01184648, 0.06461221, 0.4161499)
# test loss (mse, mae, mape) : (0.00848261, 0.07822408, 0.15727526)
#
# epoch 4 : time elapse 1.35
# train loss (mse, mae, mape) : (0.00866384, 0.05613343, 0.3284979)
# test loss (mse, mae, mape) : (0.00842754, 0.07817624, 0.15505716)
#
# epoch 5 : time elapse 1.338
# train loss (mse, mae, mape) : (0.00672038, 0.05074927, 0.30323151)
# test loss (mse, mae, mape) : (0.00771788, 0.07429003, 0.1483118)
#
# epoch 6 : time elapse 1.352
# train loss (mse, mae, mape) : (0.00593056, 0.04721942, 0.28735249)
# test loss (mse, mae, mape) : (0.00711288, 0.07062425, 0.14254008)
#
# epoch 7 : time elapse 1.335
# train loss (mse, mae, mape) : (0.00584807, 0.04603596, 0.28335638)
# test loss (mse, mae, mape) : (0.01122816, 0.08276406, 0.74765663)
#
# epoch 8 : time elapse 1.366
# train loss (mse, mae, mape) : (0.00606099, 0.04788408, 0.28908278)
# test loss (mse, mae, mape) : (0.02836082, 0.12906595, 0.69494286)
#
# epoch 9 : time elapse 1.34
# train loss (mse, mae, mape) : (0.0054877, 0.04630407, 0.25194169)
# test loss (mse, mae, mape) : (0.02105134, 0.11359184, 0.36477919)
#
# epoch 10 : time elapse 1.333
# train loss (mse, mae, mape) : (0.00467962, 0.04238162, 0.23002834)
# test loss (mse, mae, mape) : (0.02087059, 0.11039452, 0.34434083)
#
# epoch 11 : time elapse 1.347
# train loss (mse, mae, mape) : (0.00419378, 0.04013389, 0.21480703)
# test loss (mse, mae, mape) : (0.0183105, 0.09900455, 0.33902286)
#
# epoch 12 : time elapse 1.33
# train loss (mse, mae, mape) : (0.00391285, 0.03879015, 0.20840949)
# test loss (mse, mae, mape) : (0.01518944, 0.09116525, 0.34718565)
#
# epoch 13 : time elapse 1.325
# train loss (mse, mae, mape) : (0.00379726, 0.03788181, 0.20573888)
# test loss (mse, mae, mape) : (0.01528657, 0.090931, 0.37196858)
#
# epoch 14 : time elapse 1.325
# train loss (mse, mae, mape) : (0.00370355, 0.03703062, 0.20322248)
# test loss (mse, mae, mape) : (0.01894717, 0.09714494, 0.39583628)
#
# epoch 15 : time elapse 1.322
# train loss (mse, mae, mape) : (0.00363076, 0.0363417, 0.19905138)
# test loss (mse, mae, mape) : (0.02066733, 0.10025491, 0.41722963)
#
# epoch 16 : time elapse 1.328
# train loss (mse, mae, mape) : (0.00351494, 0.03554637, 0.19327278)
# test loss (mse, mae, mape) : (0.01487748, 0.08988318, 0.3881578)
#
# epoch 17 : time elapse 1.322
# train loss (mse, mae, mape) : (0.00340563, 0.03470337, 0.18541874)
# test loss (mse, mae, mape) : (0.01033288, 0.07885248, 0.26112192)
#
# epoch 18 : time elapse 1.337
# train loss (mse, mae, mape) : (0.00328187, 0.03382299, 0.17776418)
# test loss (mse, mae, mape) : (0.01311086, 0.07858393, 0.22973502)
#
# epoch 19 : time elapse 1.335
# train loss (mse, mae, mape) : (0.00321174, 0.03326072, 0.17192757)
# test loss (mse, mae, mape) : (0.01644202, 0.08219164, 0.23259004)
#
# epoch 20 : time elapse 1.334
# train loss (mse, mae, mape) : (0.00336573, 0.03356613, 0.16992884)
# test loss (mse, mae, mape) : (0.01700242, 0.08205743, 0.23667895)
#
# epoch 21 : time elapse 1.337
# train loss (mse, mae, mape) : (0.00347339, 0.03368851, 0.16965704)
# test loss (mse, mae, mape) : (0.01043112, 0.07345552, 0.18725301)
#
# epoch 22 : time elapse 1.336
# train loss (mse, mae, mape) : (0.00325922, 0.03298633, 0.16842633)
# test loss (mse, mae, mape) : (0.00807438, 0.07194461, 0.17614003)
#
# epoch 23 : time elapse 1.34
# train loss (mse, mae, mape) : (0.00319717, 0.03250895, 0.166792)
# test loss (mse, mae, mape) : (0.00794134, 0.07205379, 0.17217563)
#
# epoch 24 : time elapse 1.33
# train loss (mse, mae, mape) : (0.00313833, 0.0321124, 0.16488387)
# test loss (mse, mae, mape) : (0.00794733, 0.07262747, 0.17222814)
#
# epoch 25 : time elapse 1.338
# train loss (mse, mae, mape) : (0.00311825, 0.03179951, 0.16421036)
# test loss (mse, mae, mape) : (0.00788077, 0.0725295, 0.17154358)
#
# epoch 26 : time elapse 1.339
# train loss (mse, mae, mape) : (0.00308758, 0.03141078, 0.1631875)
# test loss (mse, mae, mape) : (0.00770698, 0.0718599, 0.16855154)
#
# epoch 27 : time elapse 1.37
# train loss (mse, mae, mape) : (0.00304768, 0.03097303, 0.16188816)
# test loss (mse, mae, mape) : (0.00754306, 0.07116318, 0.16429102)
#
# epoch 28 : time elapse 1.325
# train loss (mse, mae, mape) : (0.00300612, 0.03057841, 0.16063211)
# test loss (mse, mae, mape) : (0.00743545, 0.07069887, 0.16047179)
#
# epoch 29 : time elapse 1.33
# train loss (mse, mae, mape) : (0.00297515, 0.03028675, 0.15971905)
# test loss (mse, mae, mape) : (0.00732684, 0.07023809, 0.1571613)
#
# epoch 30 : time elapse 1.332
# train loss (mse, mae, mape) : (0.00298326, 0.03018695, 0.1592899)
# test loss (mse, mae, mape) : (0.00720003, 0.06967799, 0.15418208)
#
# Trial Number - 5
# epoch 1 : time elapse 1.363
# train loss (mse, mae, mape) : (0.0556611, 0.15532651, 0.53163694)
# test loss (mse, mae, mape) : (0.02861472, 0.12809644, 0.25688349)
#
# epoch 2 : time elapse 1.332
# train loss (mse, mae, mape) : (0.01445311, 0.07835655, 0.39937115)
# test loss (mse, mae, mape) : (0.00743179, 0.06832694, 0.15981523)
#
# epoch 3 : time elapse 1.342
# train loss (mse, mae, mape) : (0.00729674, 0.05361952, 0.2583065)
# test loss (mse, mae, mape) : (0.01042676, 0.08249428, 0.17979344)
#
# epoch 4 : time elapse 1.349
# train loss (mse, mae, mape) : (0.00617935, 0.04957367, 0.24142242)
# test loss (mse, mae, mape) : (0.00826051, 0.07402025, 0.16679193)
#
# epoch 5 : time elapse 1.352
# train loss (mse, mae, mape) : (0.00531461, 0.04463876, 0.22045916)
# test loss (mse, mae, mape) : (0.00607804, 0.06405, 0.14833621)
#
# epoch 6 : time elapse 1.336
# train loss (mse, mae, mape) : (0.00500994, 0.04366169, 0.22267934)
# test loss (mse, mae, mape) : (0.00619919, 0.06488619, 0.14860822)
#
# epoch 7 : time elapse 1.336
# train loss (mse, mae, mape) : (0.00437449, 0.04020807, 0.20668364)
# test loss (mse, mae, mape) : (0.00610806, 0.06451822, 0.14770738)
#
# epoch 8 : time elapse 1.324
# train loss (mse, mae, mape) : (0.00400482, 0.03878315, 0.19995605)
# test loss (mse, mae, mape) : (0.00603427, 0.06362298, 0.14798249)
#
# epoch 9 : time elapse 1.351
# train loss (mse, mae, mape) : (0.00387945, 0.03767026, 0.19645948)
# test loss (mse, mae, mape) : (0.00595601, 0.06274843, 0.14839005)
#
# epoch 10 : time elapse 1.318
# train loss (mse, mae, mape) : (0.00378635, 0.0368945, 0.1929371)
# test loss (mse, mae, mape) : (0.00599151, 0.06284433, 0.14930855)
#
# epoch 11 : time elapse 1.321
# train loss (mse, mae, mape) : (0.00363518, 0.0361913, 0.18959416)
# test loss (mse, mae, mape) : (0.00595535, 0.06285532, 0.14880705)
#
# epoch 12 : time elapse 1.315
# train loss (mse, mae, mape) : (0.00350636, 0.03558985, 0.18683452)
# test loss (mse, mae, mape) : (0.00612933, 0.06389248, 0.15033319)
#
# epoch 13 : time elapse 1.341
# train loss (mse, mae, mape) : (0.00337113, 0.03437703, 0.18320259)
# test loss (mse, mae, mape) : (0.0061977, 0.0643627, 0.14950902)
#
# epoch 14 : time elapse 1.35
# train loss (mse, mae, mape) : (0.00330169, 0.0339982, 0.18046698)
# test loss (mse, mae, mape) : (0.00600836, 0.06337282, 0.14795044)
#
# epoch 15 : time elapse 1.362
# train loss (mse, mae, mape) : (0.00331901, 0.03412738, 0.18022456)
# test loss (mse, mae, mape) : (0.00602982, 0.06370099, 0.14946969)
#
# epoch 16 : time elapse 1.989
# train loss (mse, mae, mape) : (0.00329966, 0.03375787, 0.17783288)
# test loss (mse, mae, mape) : (0.00611929, 0.06434813, 0.15091566)
#
# epoch 17 : time elapse 1.959
# train loss (mse, mae, mape) : (0.00327685, 0.03319682, 0.17527275)
# test loss (mse, mae, mape) : (0.00605838, 0.06396005, 0.15019652)
#
# epoch 18 : time elapse 1.333
# train loss (mse, mae, mape) : (0.00323441, 0.03258777, 0.17306098)
# test loss (mse, mae, mape) : (0.00589533, 0.06285259, 0.14842639)
#
# epoch 19 : time elapse 1.31
# train loss (mse, mae, mape) : (0.00318686, 0.03206445, 0.17060354)
# test loss (mse, mae, mape) : (0.00577664, 0.06191792, 0.14697968)
#
# epoch 20 : time elapse 1.348
# train loss (mse, mae, mape) : (0.00312316, 0.03154991, 0.16787311)
# test loss (mse, mae, mape) : (0.00563363, 0.0607898, 0.14533773)
#
# epoch 21 : time elapse 1.324
# train loss (mse, mae, mape) : (0.00306599, 0.03118235, 0.16638418)
# test loss (mse, mae, mape) : (0.00543451, 0.05939195, 0.1430838)
#
# epoch 22 : time elapse 1.334
# train loss (mse, mae, mape) : (0.00301228, 0.03086562, 0.16549278)
# test loss (mse, mae, mape) : (0.00516552, 0.05735646, 0.13961692)
#
# epoch 23 : time elapse 1.332
# train loss (mse, mae, mape) : (0.00296503, 0.03055931, 0.16513948)
# test loss (mse, mae, mape) : (0.00489347, 0.05521162, 0.13627834)
#
# epoch 24 : time elapse 1.331
# train loss (mse, mae, mape) : (0.00292788, 0.03029902, 0.16499013)
# test loss (mse, mae, mape) : (0.00469456, 0.05363934, 0.13475516)
#
# epoch 25 : time elapse 1.327
# train loss (mse, mae, mape) : (0.00290313, 0.03010049, 0.16453402)
# test loss (mse, mae, mape) : (0.00456824, 0.052713, 0.13473575)
#
# epoch 26 : time elapse 1.341
# train loss (mse, mae, mape) : (0.00288369, 0.03000373, 0.16375815)
# test loss (mse, mae, mape) : (0.00448492, 0.05219152, 0.13500232)
#
# epoch 27 : time elapse 1.345
# train loss (mse, mae, mape) : (0.00286337, 0.02986336, 0.16215832)
# test loss (mse, mae, mape) : (0.00440535, 0.05179296, 0.13521569)
#
# epoch 28 : time elapse 1.328
# train loss (mse, mae, mape) : (0.00284253, 0.02960868, 0.15992303)
# test loss (mse, mae, mape) : (0.00433257, 0.05138133, 0.13538566)
#
# epoch 29 : time elapse 1.333
# train loss (mse, mae, mape) : (0.00281951, 0.02938774, 0.15762287)
# test loss (mse, mae, mape) : (0.00431813, 0.05135884, 0.13423993)
#
# epoch 30 : time elapse 1.341
# train loss (mse, mae, mape) : (0.00278771, 0.02916858, 0.15540871)
# test loss (mse, mae, mape) : (0.00440917, 0.05219128, 0.13241482)
#
# Trial Number - 6
# epoch 1 : time elapse 1.348
# train loss (mse, mae, mape) : (0.0397403, 0.12415653, 0.80574069)
# test loss (mse, mae, mape) : (0.01772121, 0.07704152, 1.54320356)
#
# epoch 2 : time elapse 1.348
# train loss (mse, mae, mape) : (0.01105169, 0.06550391, 0.38035406)
# test loss (mse, mae, mape) : (0.01231086, 0.0699772, 0.61319431)
#
# epoch 3 : time elapse 1.337
# train loss (mse, mae, mape) : (0.0105226, 0.06377476, 0.31354708)
# test loss (mse, mae, mape) : (0.08044428, 0.15028627, 2.90685441)
#
# epoch 4 : time elapse 1.368
# train loss (mse, mae, mape) : (0.00703095, 0.04904147, 0.24710486)
# test loss (mse, mae, mape) : (0.09256422, 0.17314089, 1.72380735)
#
# epoch 5 : time elapse 1.328
# train loss (mse, mae, mape) : (0.00643651, 0.04673866, 0.23133301)
# test loss (mse, mae, mape) : (0.08767521, 0.17194729, 1.23980842)
#
# epoch 6 : time elapse 1.333
# train loss (mse, mae, mape) : (0.00558383, 0.04533967, 0.2230699)
# test loss (mse, mae, mape) : (0.07615465, 0.15220138, 0.98305404)
#
# epoch 7 : time elapse 1.338
# train loss (mse, mae, mape) : (0.00505903, 0.04446784, 0.22302607)
# test loss (mse, mae, mape) : (0.05169507, 0.11529618, 0.62562588)
#
# epoch 8 : time elapse 1.336
# train loss (mse, mae, mape) : (0.0045183, 0.04044927, 0.21036089)
# test loss (mse, mae, mape) : (0.03822144, 0.09779906, 0.46100696)
#
# epoch 9 : time elapse 1.345
# train loss (mse, mae, mape) : (0.00440719, 0.04033754, 0.21565207)
# test loss (mse, mae, mape) : (0.03762998, 0.10915803, 0.35790996)
#
# epoch 10 : time elapse 1.355
# train loss (mse, mae, mape) : (0.00417559, 0.03849488, 0.20833678)
# test loss (mse, mae, mape) : (0.02179936, 0.09236109, 0.25862979)
#
# epoch 11 : time elapse 1.349
# train loss (mse, mae, mape) : (0.00413174, 0.03776304, 0.20650628)
# test loss (mse, mae, mape) : (0.01445977, 0.0810522, 0.2149009)
#
# epoch 12 : time elapse 1.338
# train loss (mse, mae, mape) : (0.00385637, 0.03683082, 0.1999652)
# test loss (mse, mae, mape) : (0.00817489, 0.06595981, 0.18926699)
#
# epoch 13 : time elapse 1.341
# train loss (mse, mae, mape) : (0.00370503, 0.03640613, 0.19612933)
# test loss (mse, mae, mape) : (0.0053745, 0.05467755, 0.19043384)
#
# epoch 14 : time elapse 1.324
# train loss (mse, mae, mape) : (0.00364019, 0.03642411, 0.19556916)
# test loss (mse, mae, mape) : (0.00450396, 0.0509855, 0.20248039)
#
# epoch 15 : time elapse 1.352
# train loss (mse, mae, mape) : (0.00364679, 0.03667473, 0.19547655)
# test loss (mse, mae, mape) : (0.00415045, 0.04890455, 0.19767029)
#
# epoch 16 : time elapse 1.353
# train loss (mse, mae, mape) : (0.00345712, 0.03559647, 0.19298388)
# test loss (mse, mae, mape) : (0.00398867, 0.048064, 0.19220265)
#
# epoch 17 : time elapse 1.355
# train loss (mse, mae, mape) : (0.00350433, 0.03594043, 0.19369797)
# test loss (mse, mae, mape) : (0.00377527, 0.04662939, 0.18474919)
#
# epoch 18 : time elapse 1.334
# train loss (mse, mae, mape) : (0.00345789, 0.03518767, 0.19008731)
# test loss (mse, mae, mape) : (0.00380234, 0.04738324, 0.18437651)
#
# epoch 19 : time elapse 1.324
# train loss (mse, mae, mape) : (0.00335156, 0.03358862, 0.18295518)
# test loss (mse, mae, mape) : (0.00390462, 0.04888356, 0.18195604)
#
# epoch 20 : time elapse 1.33
# train loss (mse, mae, mape) : (0.00333618, 0.03312632, 0.18139683)
# test loss (mse, mae, mape) : (0.00391022, 0.04924852, 0.17507191)
#
# epoch 21 : time elapse 1.356
# train loss (mse, mae, mape) : (0.00334128, 0.03308378, 0.1829349)
# test loss (mse, mae, mape) : (0.00358006, 0.04602281, 0.17047068)
#
# epoch 22 : time elapse 1.327
# train loss (mse, mae, mape) : (0.00332914, 0.03283972, 0.17950172)
# test loss (mse, mae, mape) : (0.00336731, 0.04391507, 0.16998613)
#
# epoch 23 : time elapse 1.358
# train loss (mse, mae, mape) : (0.00328802, 0.03210893, 0.17412619)
# test loss (mse, mae, mape) : (0.00329214, 0.04341883, 0.16784275)
#
# epoch 24 : time elapse 1.364
# train loss (mse, mae, mape) : (0.0031649, 0.03093686, 0.1673426)
# test loss (mse, mae, mape) : (0.00326006, 0.04314865, 0.16834473)
#
# epoch 25 : time elapse 1.324
# train loss (mse, mae, mape) : (0.00300896, 0.02940998, 0.15504122)
# test loss (mse, mae, mape) : (0.00311772, 0.0418906, 0.17108249)
#
# epoch 26 : time elapse 1.349
# train loss (mse, mae, mape) : (0.00299474, 0.02869663, 0.14735107)
# test loss (mse, mae, mape) : (0.00300222, 0.0408035, 0.17064995)
#
# epoch 27 : time elapse 1.335
# train loss (mse, mae, mape) : (0.00297372, 0.02817904, 0.14360194)
# test loss (mse, mae, mape) : (0.00295906, 0.04039567, 0.17049583)
#
# epoch 28 : time elapse 1.33
# train loss (mse, mae, mape) : (0.00293811, 0.02811698, 0.14235723)
# test loss (mse, mae, mape) : (0.00289542, 0.03970713, 0.16772902)
#
# epoch 29 : time elapse 1.33
# train loss (mse, mae, mape) : (0.00288419, 0.02748565, 0.14068829)
# test loss (mse, mae, mape) : (0.00284683, 0.03926006, 0.16002144)
#
# epoch 30 : time elapse 1.35
# train loss (mse, mae, mape) : (0.00283926, 0.02696015, 0.14073581)
# test loss (mse, mae, mape) : (0.00290048, 0.03965491, 0.15411493)
#
# Trial Number - 7
# epoch 1 : time elapse 1.342
# train loss (mse, mae, mape) : (0.04878142, 0.14297709, 1.99142513)
# test loss (mse, mae, mape) : (0.05478544, 0.17433418, 0.46975095)
#
# epoch 2 : time elapse 1.33
# train loss (mse, mae, mape) : (0.02106553, 0.08985285, 1.55163105)
# test loss (mse, mae, mape) : (0.04517941, 0.15400588, 0.33948069)
#
# epoch 3 : time elapse 1.334
# train loss (mse, mae, mape) : (0.01193423, 0.06957237, 0.7677871)
# test loss (mse, mae, mape) : (0.05509031, 0.16844636, 0.36920814)
#
# epoch 4 : time elapse 1.343
# train loss (mse, mae, mape) : (0.01026999, 0.06400463, 0.34019356)
# test loss (mse, mae, mape) : (0.05376625, 0.17275266, 0.37872357)
#
# epoch 5 : time elapse 1.327
# train loss (mse, mae, mape) : (0.00917823, 0.06373672, 0.30288236)
# test loss (mse, mae, mape) : (0.01294883, 0.08630197, 0.19540774)
#
# epoch 6 : time elapse 1.339
# train loss (mse, mae, mape) : (0.00830983, 0.06097303, 0.31537857)
# test loss (mse, mae, mape) : (0.01007197, 0.07863717, 0.19091085)
#
# epoch 7 : time elapse 1.34
# train loss (mse, mae, mape) : (0.00726842, 0.05719896, 0.27446409)
# test loss (mse, mae, mape) : (0.00914178, 0.07766281, 0.21161335)
#
# epoch 8 : time elapse 1.357
# train loss (mse, mae, mape) : (0.00663267, 0.0547163, 0.25525946)
# test loss (mse, mae, mape) : (0.00809509, 0.07341221, 0.26776627)
#
# epoch 9 : time elapse 1.321
# train loss (mse, mae, mape) : (0.00681233, 0.05448121, 0.24185588)
# test loss (mse, mae, mape) : (0.0082609, 0.07338204, 0.32875299)
#
# epoch 10 : time elapse 1.358
# train loss (mse, mae, mape) : (0.00640131, 0.05350385, 0.24420258)
# test loss (mse, mae, mape) : (0.00781562, 0.07211867, 0.32374618)
#
# epoch 11 : time elapse 1.335
# train loss (mse, mae, mape) : (0.00566085, 0.05022775, 0.23622653)
# test loss (mse, mae, mape) : (0.00692081, 0.0671908, 0.18303772)
#
# epoch 12 : time elapse 1.341
# train loss (mse, mae, mape) : (0.00628582, 0.04993178, 0.2309567)
# test loss (mse, mae, mape) : (0.00727973, 0.06811678, 0.17765971)
#
# epoch 13 : time elapse 1.357
# train loss (mse, mae, mape) : (0.00643091, 0.05076662, 0.23512416)
# test loss (mse, mae, mape) : (0.00708259, 0.06766277, 0.17168683)
#
# epoch 14 : time elapse 1.329
# train loss (mse, mae, mape) : (0.00558383, 0.04609908, 0.20466611)
# test loss (mse, mae, mape) : (0.00821973, 0.07324676, 0.17030531)
#
# epoch 15 : time elapse 1.337
# train loss (mse, mae, mape) : (0.00554347, 0.04806207, 0.21799747)
# test loss (mse, mae, mape) : (0.00635594, 0.06397453, 0.16639672)
#
# epoch 16 : time elapse 1.333
# train loss (mse, mae, mape) : (0.00639326, 0.05076378, 0.24633106)
# test loss (mse, mae, mape) : (0.00566882, 0.06021354, 0.15705262)
#
# epoch 17 : time elapse 1.346
# train loss (mse, mae, mape) : (0.00967742, 0.05613697, 0.27526761)
# test loss (mse, mae, mape) : (0.00699297, 0.06649236, 0.18279622)
#
# epoch 18 : time elapse 1.334
# train loss (mse, mae, mape) : (0.00663105, 0.05133063, 0.31604957)
# test loss (mse, mae, mape) : (0.00815525, 0.07222201, 0.21346504)
#
# epoch 19 : time elapse 1.351
# train loss (mse, mae, mape) : (0.00547193, 0.04778329, 0.2804712)
# test loss (mse, mae, mape) : (0.00884447, 0.07617516, 0.24648758)
#
# epoch 20 : time elapse 1.332
# train loss (mse, mae, mape) : (0.00505712, 0.04543408, 0.25639039)
# test loss (mse, mae, mape) : (0.00988568, 0.08123851, 0.281354)
#
# epoch 21 : time elapse 1.334
# train loss (mse, mae, mape) : (0.00476875, 0.0436756, 0.25238635)
# test loss (mse, mae, mape) : (0.01022661, 0.08185855, 0.30115853)
#
# epoch 22 : time elapse 1.331
# train loss (mse, mae, mape) : (0.00563299, 0.04777683, 0.27878591)
# test loss (mse, mae, mape) : (0.00998263, 0.08105475, 0.26782495)
#
# epoch 23 : time elapse 1.322
# train loss (mse, mae, mape) : (0.00505954, 0.04452244, 0.24408421)
# test loss (mse, mae, mape) : (0.00839941, 0.07491559, 0.24859303)
#
# epoch 24 : time elapse 1.338
# train loss (mse, mae, mape) : (0.00463499, 0.04363939, 0.25512811)
# test loss (mse, mae, mape) : (0.00698701, 0.06879153, 0.25360963)
#
# epoch 25 : time elapse 1.334
# train loss (mse, mae, mape) : (0.00436558, 0.042842, 0.25597941)
# test loss (mse, mae, mape) : (0.00701607, 0.06895334, 0.24415656)
#
# epoch 26 : time elapse 1.368
# train loss (mse, mae, mape) : (0.0040736, 0.04094931, 0.24861406)
# test loss (mse, mae, mape) : (0.00739018, 0.07062941, 0.24165734)
#
# epoch 27 : time elapse 1.333
# train loss (mse, mae, mape) : (0.00406458, 0.04060588, 0.26755914)
# test loss (mse, mae, mape) : (0.00760995, 0.07158042, 0.23878851)
#
# epoch 28 : time elapse 1.358
# train loss (mse, mae, mape) : (0.00394111, 0.03930517, 0.26650602)
# test loss (mse, mae, mape) : (0.00758898, 0.07128936, 0.23672912)
#
# epoch 29 : time elapse 1.346
# train loss (mse, mae, mape) : (0.00385734, 0.03737284, 0.23827133)
# test loss (mse, mae, mape) : (0.00740651, 0.07011865, 0.22842935)
#
# epoch 30 : time elapse 1.332
# train loss (mse, mae, mape) : (0.00395378, 0.0371042, 0.23074129)
# test loss (mse, mae, mape) : (0.00733709, 0.06956542, 0.22177837)
#
# Trial Number - 8
# epoch 1 : time elapse 1.344
# train loss (mse, mae, mape) : (0.02568571, 0.10376065, 0.57461943)
# test loss (mse, mae, mape) : (0.0138196, 0.09300868, 0.30480045)
#
# epoch 2 : time elapse 1.355
# train loss (mse, mae, mape) : (0.01230656, 0.07241474, 0.29590335)
# test loss (mse, mae, mape) : (0.02711169, 0.12815701, 0.47652854)
#
# epoch 3 : time elapse 1.327
# train loss (mse, mae, mape) : (0.0121168, 0.06407014, 0.26622488)
# test loss (mse, mae, mape) : (0.01002773, 0.07997835, 0.59439417)
#
# epoch 4 : time elapse 1.332
# train loss (mse, mae, mape) : (0.00995545, 0.06119249, 0.3012824)
# test loss (mse, mae, mape) : (0.02519942, 0.12339459, 1.55599852)
#
# epoch 5 : time elapse 1.327
# train loss (mse, mae, mape) : (0.00888011, 0.05893652, 0.30674043)
# test loss (mse, mae, mape) : (0.01958923, 0.11211983, 1.47088247)
#
# epoch 6 : time elapse 1.328
# train loss (mse, mae, mape) : (0.00533826, 0.04441354, 0.24293843)
# test loss (mse, mae, mape) : (0.01561631, 0.10317883, 0.91015945)
#
# epoch 7 : time elapse 1.341
# train loss (mse, mae, mape) : (0.00418149, 0.03854915, 0.20283858)
# test loss (mse, mae, mape) : (0.01570959, 0.1018214, 0.57638159)
#
# epoch 8 : time elapse 1.323
# train loss (mse, mae, mape) : (0.0038271, 0.03675494, 0.18679427)
# test loss (mse, mae, mape) : (0.01499564, 0.09877036, 0.44961592)
#
# epoch 9 : time elapse 1.355
# train loss (mse, mae, mape) : (0.00368066, 0.03621179, 0.18131787)
# test loss (mse, mae, mape) : (0.01415334, 0.09565784, 0.40734715)
#
# epoch 10 : time elapse 1.337
# train loss (mse, mae, mape) : (0.00356459, 0.03565584, 0.17797037)
# test loss (mse, mae, mape) : (0.01314155, 0.09167819, 0.38434401)
#
# epoch 11 : time elapse 1.356
# train loss (mse, mae, mape) : (0.00341075, 0.03460407, 0.17396845)
# test loss (mse, mae, mape) : (0.01220476, 0.08793976, 0.38116233)
#
# epoch 12 : time elapse 1.342
# train loss (mse, mae, mape) : (0.00327437, 0.03356729, 0.17025835)
# test loss (mse, mae, mape) : (0.01139757, 0.08519444, 0.38824796)
#
# epoch 13 : time elapse 1.34
# train loss (mse, mae, mape) : (0.00315916, 0.03263918, 0.16617983)
# test loss (mse, mae, mape) : (0.01022003, 0.08095913, 0.37971191)
#
# epoch 14 : time elapse 1.334
# train loss (mse, mae, mape) : (0.00298718, 0.03120577, 0.16011122)
# test loss (mse, mae, mape) : (0.0089139, 0.07566589, 0.34758239)
#
# epoch 15 : time elapse 1.332
# train loss (mse, mae, mape) : (0.00284667, 0.030142, 0.15583235)
# test loss (mse, mae, mape) : (0.00787635, 0.07080705, 0.31148321)
#
# epoch 16 : time elapse 1.337
# train loss (mse, mae, mape) : (0.00274926, 0.02930587, 0.15294612)
# test loss (mse, mae, mape) : (0.00724129, 0.067532, 0.2959302)
#
# epoch 17 : time elapse 1.357
# train loss (mse, mae, mape) : (0.00269644, 0.02873713, 0.15096877)
# test loss (mse, mae, mape) : (0.00687139, 0.0655736, 0.29776959)
#
# epoch 18 : time elapse 1.346
# train loss (mse, mae, mape) : (0.00267214, 0.02830695, 0.1494554)
# test loss (mse, mae, mape) : (0.00671681, 0.06460653, 0.30780693)
#
# epoch 19 : time elapse 1.341
# train loss (mse, mae, mape) : (0.0026626, 0.02799834, 0.14824619)
# test loss (mse, mae, mape) : (0.00678518, 0.06480171, 0.31854098)
#
# epoch 20 : time elapse 1.345
# train loss (mse, mae, mape) : (0.00265542, 0.0277309, 0.14704865)
# test loss (mse, mae, mape) : (0.0069332, 0.06555087, 0.32202192)
#
# epoch 21 : time elapse 1.335
# train loss (mse, mae, mape) : (0.00265232, 0.0275934, 0.14624139)
# test loss (mse, mae, mape) : (0.00708074, 0.06641975, 0.32170928)
#
# epoch 22 : time elapse 1.339
# train loss (mse, mae, mape) : (0.00265316, 0.02753879, 0.1457061)
# test loss (mse, mae, mape) : (0.00722128, 0.06728326, 0.31757795)
#
# epoch 23 : time elapse 1.335
# train loss (mse, mae, mape) : (0.00266175, 0.02748878, 0.1452063)
# test loss (mse, mae, mape) : (0.00737441, 0.0681666, 0.30838535)
#
# epoch 24 : time elapse 1.352
# train loss (mse, mae, mape) : (0.00266837, 0.02743805, 0.1445188)
# test loss (mse, mae, mape) : (0.00744881, 0.06861901, 0.29122838)
#
# epoch 25 : time elapse 1.323
# train loss (mse, mae, mape) : (0.00266988, 0.0273721, 0.14359694)
# test loss (mse, mae, mape) : (0.00745134, 0.06855949, 0.27322235)
#
# epoch 26 : time elapse 1.329
# train loss (mse, mae, mape) : (0.00267138, 0.02727558, 0.14266725)
# test loss (mse, mae, mape) : (0.00742775, 0.06826875, 0.2603033)
#
# epoch 27 : time elapse 1.339
# train loss (mse, mae, mape) : (0.00267569, 0.02716704, 0.14196155)
# test loss (mse, mae, mape) : (0.00735357, 0.06772683, 0.2518347)
#
# epoch 28 : time elapse 1.351
# train loss (mse, mae, mape) : (0.00268395, 0.02710632, 0.14167529)
# test loss (mse, mae, mape) : (0.00723016, 0.06702428, 0.24591585)
#
# epoch 29 : time elapse 1.366
# train loss (mse, mae, mape) : (0.00269562, 0.02708216, 0.14178538)
# test loss (mse, mae, mape) : (0.00708997, 0.0662933, 0.24175188)
#
# epoch 30 : time elapse 1.331
# train loss (mse, mae, mape) : (0.00271053, 0.02710845, 0.14215717)
# test loss (mse, mae, mape) : (0.00695884, 0.06563213, 0.23925833)
#
# Trial Number - 9
# epoch 1 : time elapse 1.328
# train loss (mse, mae, mape) : (0.03531253, 0.10560395, 0.31034138)
# test loss (mse, mae, mape) : (0.00714319, 0.07100883, 0.19693514)
#
# epoch 2 : time elapse 1.333
# train loss (mse, mae, mape) : (0.01887669, 0.08244765, 0.36916493)
# test loss (mse, mae, mape) : (0.00611525, 0.0647585, 0.18103884)
#
# epoch 3 : time elapse 1.329
# train loss (mse, mae, mape) : (0.00812309, 0.05717144, 0.37513066)
# test loss (mse, mae, mape) : (0.00634711, 0.06621164, 0.184012)
#
# epoch 4 : time elapse 1.348
# train loss (mse, mae, mape) : (0.00644471, 0.04799242, 0.36578954)
# test loss (mse, mae, mape) : (0.00633943, 0.0661484, 0.18060116)
#
# epoch 5 : time elapse 1.357
# train loss (mse, mae, mape) : (0.00543797, 0.04306812, 0.33425925)
# test loss (mse, mae, mape) : (0.00617719, 0.06529059, 0.17461611)
#
# epoch 6 : time elapse 1.319
# train loss (mse, mae, mape) : (0.00450893, 0.04011638, 0.26961112)
# test loss (mse, mae, mape) : (0.00601403, 0.064347, 0.16975265)
#
# epoch 7 : time elapse 1.342
# train loss (mse, mae, mape) : (0.0039315, 0.03753681, 0.23085957)
# test loss (mse, mae, mape) : (0.00592445, 0.06380273, 0.16527167)
#
# epoch 8 : time elapse 1.316
# train loss (mse, mae, mape) : (0.00360631, 0.03598067, 0.2131855)
# test loss (mse, mae, mape) : (0.00586724, 0.06340046, 0.16178693)
#
# epoch 9 : time elapse 1.34
# train loss (mse, mae, mape) : (0.0034508, 0.03518597, 0.20391306)
# test loss (mse, mae, mape) : (0.00585364, 0.06324752, 0.1597413)
#
# epoch 10 : time elapse 1.335
# train loss (mse, mae, mape) : (0.00337296, 0.03485809, 0.19762204)
# test loss (mse, mae, mape) : (0.00588891, 0.06339358, 0.15932914)
#
# epoch 11 : time elapse 1.347
# train loss (mse, mae, mape) : (0.00334591, 0.03474037, 0.19380605)
# test loss (mse, mae, mape) : (0.00594331, 0.06365024, 0.15968551)
#
# epoch 12 : time elapse 1.343
# train loss (mse, mae, mape) : (0.00332936, 0.03453301, 0.19019558)
# test loss (mse, mae, mape) : (0.00600308, 0.06392923, 0.16016716)
#
# epoch 13 : time elapse 1.329
# train loss (mse, mae, mape) : (0.00332741, 0.0344079, 0.18816802)
# test loss (mse, mae, mape) : (0.00606494, 0.06423024, 0.16210658)
#
# epoch 14 : time elapse 1.317
# train loss (mse, mae, mape) : (0.00330053, 0.03416092, 0.18817528)
# test loss (mse, mae, mape) : (0.00611257, 0.0644584, 0.16466807)
#
# epoch 15 : time elapse 1.339
# train loss (mse, mae, mape) : (0.00331283, 0.03386901, 0.18640463)
# test loss (mse, mae, mape) : (0.00614385, 0.06460211, 0.16769454)
#
# epoch 16 : time elapse 1.312
# train loss (mse, mae, mape) : (0.00327227, 0.03337434, 0.18413814)
# test loss (mse, mae, mape) : (0.00614175, 0.06456379, 0.17020924)
#
# epoch 17 : time elapse 1.33
# train loss (mse, mae, mape) : (0.0032487, 0.03306631, 0.18166237)
# test loss (mse, mae, mape) : (0.00612304, 0.06441752, 0.1719639)
#
# epoch 18 : time elapse 1.342
# train loss (mse, mae, mape) : (0.00333401, 0.03317004, 0.18161348)
# test loss (mse, mae, mape) : (0.00606849, 0.06408993, 0.17392522)
#
# epoch 19 : time elapse 1.331
# train loss (mse, mae, mape) : (0.00335805, 0.03325368, 0.18025099)
# test loss (mse, mae, mape) : (0.00607948, 0.06417821, 0.17569671)
#
# epoch 20 : time elapse 1.331
# train loss (mse, mae, mape) : (0.00349149, 0.03375468, 0.18244147)
# test loss (mse, mae, mape) : (0.00605236, 0.06402262, 0.17385465)
#
# epoch 21 : time elapse 1.335
# train loss (mse, mae, mape) : (0.00360003, 0.03435409, 0.18322656)
# test loss (mse, mae, mape) : (0.00594526, 0.06340963, 0.16692838)
#
# epoch 22 : time elapse 1.332
# train loss (mse, mae, mape) : (0.0040115, 0.03587689, 0.19144099)
# test loss (mse, mae, mape) : (0.00580616, 0.06265179, 0.15777212)
#
# epoch 23 : time elapse 1.332
# train loss (mse, mae, mape) : (0.00434158, 0.03812837, 0.19581402)
# test loss (mse, mae, mape) : (0.00599494, 0.06345119, 0.156629)
#
# epoch 24 : time elapse 1.347
# train loss (mse, mae, mape) : (0.00500773, 0.04154585, 0.21018031)
# test loss (mse, mae, mape) : (0.00685682, 0.06744128, 0.18479933)
#
# epoch 25 : time elapse 1.34
# train loss (mse, mae, mape) : (0.00527087, 0.04211123, 0.22118161)
# test loss (mse, mae, mape) : (0.00939751, 0.07832315, 0.25000712)
#
# epoch 26 : time elapse 1.331
# train loss (mse, mae, mape) : (0.00493117, 0.04043178, 0.22392011)
# test loss (mse, mae, mape) : (0.01193809, 0.08767715, 0.27128832)
#
# epoch 27 : time elapse 1.348
# train loss (mse, mae, mape) : (0.0047234, 0.04012372, 0.22541701)
# test loss (mse, mae, mape) : (0.01157454, 0.08686367, 0.25377833)
#
# epoch 28 : time elapse 1.336
# train loss (mse, mae, mape) : (0.0050504, 0.04122031, 0.22851174)
# test loss (mse, mae, mape) : (0.00998959, 0.08107852, 0.23433009)
#
# epoch 29 : time elapse 1.334
# train loss (mse, mae, mape) : (0.00520659, 0.04171877, 0.22089108)
# test loss (mse, mae, mape) : (0.00868772, 0.07582334, 0.21313661)
#
# epoch 30 : time elapse 1.338
# train loss (mse, mae, mape) : (0.00448332, 0.03759864, 0.19306149)
# test loss (mse, mae, mape) : (0.00778798, 0.07185275, 0.19690616)
#
# Trial Number - 10
# epoch 1 : time elapse 1.344
# train loss (mse, mae, mape) : (0.04320144, 0.14102802, 0.54215413)
# test loss (mse, mae, mape) : (0.01256553, 0.09053005, 0.20582723)
#
# epoch 2 : time elapse 1.353
# train loss (mse, mae, mape) : (0.01561289, 0.07558037, 0.29093987)
# test loss (mse, mae, mape) : (0.010603, 0.08567809, 0.20552197)
#
# epoch 3 : time elapse 1.35
# train loss (mse, mae, mape) : (0.0069494, 0.05433718, 0.26125428)
# test loss (mse, mae, mape) : (0.01112172, 0.08894461, 0.23464331)
#
# epoch 4 : time elapse 1.325
# train loss (mse, mae, mape) : (0.00479129, 0.0434945, 0.22071877)
# test loss (mse, mae, mape) : (0.01101065, 0.08889761, 0.23806341)
#
# epoch 5 : time elapse 1.317
# train loss (mse, mae, mape) : (0.00410942, 0.0407983, 0.21048359)
# test loss (mse, mae, mape) : (0.01043383, 0.08613576, 0.22922233)
#
# epoch 6 : time elapse 1.331
# train loss (mse, mae, mape) : (0.00388654, 0.03914229, 0.20365247)
# test loss (mse, mae, mape) : (0.01012404, 0.08473044, 0.22489271)
#
# epoch 7 : time elapse 1.345
# train loss (mse, mae, mape) : (0.00379608, 0.03829003, 0.19947491)
# test loss (mse, mae, mape) : (0.0098536, 0.08352237, 0.2202425)
#
# epoch 8 : time elapse 1.306
# train loss (mse, mae, mape) : (0.00369625, 0.03743044, 0.19582847)
# test loss (mse, mae, mape) : (0.00961229, 0.08246741, 0.21654229)
#
# epoch 9 : time elapse 1.324
# train loss (mse, mae, mape) : (0.00357626, 0.0364771, 0.19252917)
# test loss (mse, mae, mape) : (0.00940968, 0.08158833, 0.21423706)
#
# epoch 10 : time elapse 1.345
# train loss (mse, mae, mape) : (0.00346259, 0.0355538, 0.18867674)
# test loss (mse, mae, mape) : (0.00920968, 0.08069196, 0.21277544)
#
# epoch 11 : time elapse 1.332
# train loss (mse, mae, mape) : (0.00341347, 0.03492941, 0.18566748)
# test loss (mse, mae, mape) : (0.00898536, 0.07964168, 0.21114952)
#
# epoch 12 : time elapse 1.341
# train loss (mse, mae, mape) : (0.00337256, 0.03424828, 0.18222981)
# test loss (mse, mae, mape) : (0.00868399, 0.07814168, 0.20811497)
#
# epoch 13 : time elapse 1.343
# train loss (mse, mae, mape) : (0.0033642, 0.03386941, 0.18069036)
# test loss (mse, mae, mape) : (0.00831259, 0.07615405, 0.20393214)
#
# epoch 14 : time elapse 1.585
# train loss (mse, mae, mape) : (0.00336153, 0.03370111, 0.18051667)
# test loss (mse, mae, mape) : (0.00792783, 0.07399041, 0.20021669)
#
# epoch 15 : time elapse 1.905
# train loss (mse, mae, mape) : (0.00345413, 0.03406705, 0.18298514)
# test loss (mse, mae, mape) : (0.00765257, 0.07234697, 0.19966075)
#
# epoch 16 : time elapse 1.704
# train loss (mse, mae, mape) : (0.00351504, 0.03421337, 0.18449917)
# test loss (mse, mae, mape) : (0.00726208, 0.0701919, 0.19837407)
#
# epoch 17 : time elapse 1.328
# train loss (mse, mae, mape) : (0.00332406, 0.03307691, 0.18028655)
# test loss (mse, mae, mape) : (0.006807, 0.06772997, 0.1966398)
#
# epoch 18 : time elapse 1.333
# train loss (mse, mae, mape) : (0.00324066, 0.03262049, 0.17855233)
# test loss (mse, mae, mape) : (0.00642255, 0.06565482, 0.19573378)
#
# epoch 19 : time elapse 1.327
# train loss (mse, mae, mape) : (0.00318633, 0.03261793, 0.18014553)
# test loss (mse, mae, mape) : (0.0062416, 0.06468821, 0.19618907)
#
# epoch 20 : time elapse 1.343
# train loss (mse, mae, mape) : (0.00311295, 0.03255388, 0.18345472)
# test loss (mse, mae, mape) : (0.00619467, 0.06442989, 0.19764031)
#
# epoch 21 : time elapse 1.333
# train loss (mse, mae, mape) : (0.00301906, 0.03206156, 0.1815315)
# test loss (mse, mae, mape) : (0.00620552, 0.06448955, 0.19921636)
#
# epoch 22 : time elapse 1.345
# train loss (mse, mae, mape) : (0.00302763, 0.03209335, 0.1807942)
# test loss (mse, mae, mape) : (0.0062602, 0.06479315, 0.201641)
#
# epoch 23 : time elapse 1.337
# train loss (mse, mae, mape) : (0.0030302, 0.0322138, 0.18203591)
# test loss (mse, mae, mape) : (0.00637169, 0.06538768, 0.20502109)
#
# epoch 24 : time elapse 1.331
# train loss (mse, mae, mape) : (0.00301689, 0.03228756, 0.18216774)
# test loss (mse, mae, mape) : (0.0065194, 0.06615585, 0.20921804)
#
# epoch 25 : time elapse 1.342
# train loss (mse, mae, mape) : (0.00299502, 0.0322852, 0.18094075)
# test loss (mse, mae, mape) : (0.00666349, 0.06685408, 0.2131188)
#
# epoch 26 : time elapse 1.363
# ...
# test loss (mse, mae, mape) : (0.0038692, 0.04911639, 0.1277944)
#
# epoch 23 : time elapse 1.335
# train loss (mse, mae, mape) : (0.00315865, 0.03171683, 0.17888613)
# test loss (mse, mae, mape) : (0.00490672, 0.05771961, 0.13311114)
#
# epoch 24 : time elapse 1.318
# train loss (mse, mae, mape) : (0.00313104, 0.03176405, 0.18077746)
# test loss (mse, mae, mape) : (0.00502797, 0.05856194, 0.13386856)
#
# epoch 25 : time elapse 1.331
# train loss (mse, mae, mape) : (0.0029909, 0.03103176, 0.17565691)
# test loss (mse, mae, mape) : (0.0047104, 0.05630764, 0.13212113)
#
# epoch 26 : time elapse 1.324
# train loss (mse, mae, mape) : (0.00289514, 0.03044525, 0.17058199)
# test loss (mse, mae, mape) : (0.00441217, 0.05402802, 0.13106412)
#
# epoch 27 : time elapse 1.328
# train loss (mse, mae, mape) : (0.00284523, 0.03018153, 0.16815322)
# test loss (mse, mae, mape) : (0.00417203, 0.05210254, 0.13086498)
#
# epoch 28 : time elapse 1.338
# train loss (mse, mae, mape) : (0.00281872, 0.03009843, 0.16714226)
# test loss (mse, mae, mape) : (0.00399836, 0.05070556, 0.13153122)
#
# epoch 29 : time elapse 1.351
# train loss (mse, mae, mape) : (0.00281087, 0.03009301, 0.16675978)
# test loss (mse, mae, mape) : (0.00387339, 0.04973188, 0.1330441)
#
# epoch 30 : time elapse 1.357
# train loss (mse, mae, mape) : (0.00282173, 0.03007724, 0.16657846)
# test loss (mse, mae, mape) : (0.00376711, 0.04891477, 0.13488794)
#
# Trial Number - 28
# epoch 1 : time elapse 1.334
# train loss (mse, mae, mape) : (0.05023052, 0.13197335, 0.37895085)
# test loss (mse, mae, mape) : (0.04081966, 0.138051, 0.45570362)
#
# epoch 2 : time elapse 1.364
# train loss (mse, mae, mape) : (0.03805391, 0.11548551, 0.69355613)
# test loss (mse, mae, mape) : (0.0919874, 0.19176004, 0.87012375)
#
# epoch 3 : time elapse 1.359
# train loss (mse, mae, mape) : (0.04177315, 0.12665812, 0.65485545)
# test loss (mse, mae, mape) : (0.00878659, 0.07431582, 0.18012978)
#
# epoch 4 : time elapse 1.342
# train loss (mse, mae, mape) : (0.02053607, 0.08053996, 0.37497856)
# test loss (mse, mae, mape) : (0.0063542, 0.06322343, 0.16561949)
#
# epoch 5 : time elapse 1.324
# train loss (mse, mae, mape) : (0.01244425, 0.06476368, 0.29795372)
# test loss (mse, mae, mape) : (0.00682809, 0.06103874, 0.16691006)
#
# epoch 6 : time elapse 1.344
# train loss (mse, mae, mape) : (0.00880629, 0.05974494, 0.3028453)
# test loss (mse, mae, mape) : (0.00534476, 0.05502737, 0.15467309)
#
# epoch 7 : time elapse 1.338
# train loss (mse, mae, mape) : (0.0062908, 0.04818503, 0.24738465)
# test loss (mse, mae, mape) : (0.00440816, 0.05029077, 0.15349686)
#
# epoch 8 : time elapse 1.332
# train loss (mse, mae, mape) : (0.00460211, 0.04048705, 0.22670268)
# test loss (mse, mae, mape) : (0.00455383, 0.05406448, 0.15024617)
#
# epoch 9 : time elapse 1.33
# train loss (mse, mae, mape) : (0.00387097, 0.03637871, 0.20007491)
# test loss (mse, mae, mape) : (0.00436817, 0.0528581, 0.14663531)
#
# epoch 10 : time elapse 1.335
# train loss (mse, mae, mape) : (0.00340754, 0.03331136, 0.18335808)
# test loss (mse, mae, mape) : (0.00420552, 0.05178016, 0.1454059)
#
# epoch 11 : time elapse 1.343
# train loss (mse, mae, mape) : (0.00325798, 0.03205212, 0.17604786)
# test loss (mse, mae, mape) : (0.00409228, 0.05106244, 0.14503316)
#
# epoch 12 : time elapse 1.361
# train loss (mse, mae, mape) : (0.0031787, 0.03133153, 0.1712996)
# test loss (mse, mae, mape) : (0.00399322, 0.05053047, 0.14420489)
#
# epoch 13 : time elapse 1.338
# train loss (mse, mae, mape) : (0.00315583, 0.03106928, 0.17107779)
# test loss (mse, mae, mape) : (0.00390709, 0.05013471, 0.14268792)
#
# epoch 14 : time elapse 1.329
# train loss (mse, mae, mape) : (0.00314747, 0.03098649, 0.17184548)
# test loss (mse, mae, mape) : (0.00384202, 0.04985843, 0.14085887)
#
# epoch 15 : time elapse 1.342
# train loss (mse, mae, mape) : (0.0031469, 0.03089114, 0.17212756)
# test loss (mse, mae, mape) : (0.00379707, 0.04962021, 0.13920554)
#
# epoch 16 : time elapse 1.337
# train loss (mse, mae, mape) : (0.00314511, 0.03075589, 0.17150849)
# test loss (mse, mae, mape) : (0.00373945, 0.04917632, 0.13743697)
#
# epoch 17 : time elapse 1.356
# train loss (mse, mae, mape) : (0.00313089, 0.03052299, 0.16966857)
# test loss (mse, mae, mape) : (0.00363504, 0.04833877, 0.13432172)
#
# epoch 18 : time elapse 1.384
# train loss (mse, mae, mape) : (0.00308948, 0.03019732, 0.16709995)
# test loss (mse, mae, mape) : (0.00349317, 0.04724551, 0.12940947)
#
# epoch 19 : time elapse 1.335
# train loss (mse, mae, mape) : (0.00302085, 0.02985756, 0.16491156)
# test loss (mse, mae, mape) : (0.00335836, 0.04634155, 0.12401756)
#
# epoch 20 : time elapse 1.338
# train loss (mse, mae, mape) : (0.00303057, 0.02994969, 0.16551364)
# test loss (mse, mae, mape) : (0.00326058, 0.04586428, 0.11991137)
#
# epoch 21 : time elapse 1.34
# train loss (mse, mae, mape) : (0.0030644, 0.03014173, 0.16686514)
# test loss (mse, mae, mape) : (0.00321077, 0.04580922, 0.11793777)
#
# epoch 22 : time elapse 1.347
# train loss (mse, mae, mape) : (0.00305805, 0.03020169, 0.16736154)
# test loss (mse, mae, mape) : (0.00321566, 0.04605293, 0.11707051)
#
# epoch 23 : time elapse 1.333
# train loss (mse, mae, mape) : (0.00307224, 0.03035224, 0.16827309)
# test loss (mse, mae, mape) : (0.00326409, 0.04655718, 0.11738226)
#
# epoch 24 : time elapse 1.331
# train loss (mse, mae, mape) : (0.00305062, 0.03033505, 0.16828563)
# test loss (mse, mae, mape) : (0.00334191, 0.0471141, 0.11791504)
#
# epoch 25 : time elapse 1.337
# train loss (mse, mae, mape) : (0.00300576, 0.03019281, 0.16753727)
# test loss (mse, mae, mape) : (0.00342786, 0.04760417, 0.11825673)
#
# epoch 26 : time elapse 1.34
# train loss (mse, mae, mape) : (0.00296695, 0.03004613, 0.1663845)
# test loss (mse, mae, mape) : (0.00349896, 0.04796801, 0.11844243)
#
# epoch 27 : time elapse 1.345
# train loss (mse, mae, mape) : (0.00293679, 0.02992286, 0.16533159)
# test loss (mse, mae, mape) : (0.00354949, 0.04819231, 0.11845102)
#
# epoch 28 : time elapse 1.345
# train loss (mse, mae, mape) : (0.00291063, 0.02977452, 0.16428084)
# test loss (mse, mae, mape) : (0.00357717, 0.04828447, 0.11828646)
#
# epoch 29 : time elapse 1.327
# train loss (mse, mae, mape) : (0.00288088, 0.02955293, 0.16293414)
# test loss (mse, mae, mape) : (0.00356742, 0.0481811, 0.11789557)
#
# epoch 30 : time elapse 1.339
# train loss (mse, mae, mape) : (0.0028435, 0.0292194, 0.1611286)
# test loss (mse, mae, mape) : (0.00350166, 0.04777566, 0.11708329)
#
# Trial Number - 29
# epoch 1 : time elapse 1.363
# train loss (mse, mae, mape) : (0.05321949, 0.13714426, 3.96915607)
# test loss (mse, mae, mape) : (0.01357166, 0.09182379, 0.35963956)
#
# epoch 2 : time elapse 1.34
# train loss (mse, mae, mape) : (0.03936935, 0.11518726, 2.76723863)
# test loss (mse, mae, mape) : (0.01311304, 0.09503088, 0.25580666)
#
# epoch 3 : time elapse 1.344
# train loss (mse, mae, mape) : (0.01759958, 0.07521922, 0.50428235)
# test loss (mse, mae, mape) : (0.18600911, 0.32093492, 1.59508102)
#
# epoch 4 : time elapse 1.362
# train loss (mse, mae, mape) : (0.01328953, 0.06688902, 0.35248998)
# test loss (mse, mae, mape) : (0.15192456, 0.29607404, 1.08226572)
#
# epoch 5 : time elapse 1.367
# train loss (mse, mae, mape) : (0.01158766, 0.06604483, 0.32509974)
# test loss (mse, mae, mape) : (0.11968558, 0.2639308, 0.76873244)
#
# epoch 6 : time elapse 1.345
# train loss (mse, mae, mape) : (0.00742343, 0.05489525, 0.26222914)
# test loss (mse, mae, mape) : (0.09985492, 0.24096891, 0.61350823)
#
# epoch 7 : time elapse 1.345
# train loss (mse, mae, mape) : (0.00461118, 0.0440592, 0.21510726)
# test loss (mse, mae, mape) : (0.0807831, 0.21364544, 0.49786528)
#
# epoch 8 : time elapse 1.368
# train loss (mse, mae, mape) : (0.00373658, 0.03850788, 0.19088891)
# test loss (mse, mae, mape) : (0.07737318, 0.20645819, 0.50591393)
#
# epoch 9 : time elapse 1.34
# train loss (mse, mae, mape) : (0.00341911, 0.03574841, 0.17805533)
# test loss (mse, mae, mape) : (0.07855772, 0.20863227, 0.56365241)
#
# epoch 10 : time elapse 1.343
# train loss (mse, mae, mape) : (0.00325789, 0.03402837, 0.17227286)
# test loss (mse, mae, mape) : (0.074276, 0.20354863, 0.58983532)
#
# epoch 11 : time elapse 1.325
# train loss (mse, mae, mape) : (0.00328226, 0.03404005, 0.17359791)
# test loss (mse, mae, mape) : (0.06774425, 0.19586186, 0.6015975)
#
# epoch 12 : time elapse 1.326
# train loss (mse, mae, mape) : (0.00334617, 0.03458859, 0.17668482)
# test loss (mse, mae, mape) : (0.05691589, 0.17897889, 0.55047196)
#
# epoch 13 : time elapse 1.339
# train loss (mse, mae, mape) : (0.00348065, 0.03547965, 0.18124092)
# test loss (mse, mae, mape) : (0.04350721, 0.15589404, 0.4559552)
#
# epoch 14 : time elapse 1.358
# train loss (mse, mae, mape) : (0.00381758, 0.03779298, 0.18850261)
# test loss (mse, mae, mape) : (0.02131481, 0.10520209, 0.27747363)
#
# epoch 15 : time elapse 1.332
# train loss (mse, mae, mape) : (0.00440919, 0.04159116, 0.19804698)
# test loss (mse, mae, mape) : (0.01094424, 0.07882502, 0.19006759)
#
# epoch 16 : time elapse 1.353
# train loss (mse, mae, mape) : (0.00454038, 0.0424618, 0.20102871)
# test loss (mse, mae, mape) : (0.0075423, 0.07113207, 0.1679346)
#
# epoch 17 : time elapse 1.33
# train loss (mse, mae, mape) : (0.00406498, 0.03983725, 0.19575504)
# test loss (mse, mae, mape) : (0.00740222, 0.06985757, 0.16621224)
#
# epoch 18 : time elapse 1.327
# train loss (mse, mae, mape) : (0.00369059, 0.0377992, 0.20231674)
# test loss (mse, mae, mape) : (0.00704046, 0.06765647, 0.16183573)
#
# epoch 19 : time elapse 1.349
# train loss (mse, mae, mape) : (0.00343689, 0.03594709, 0.19796612)
# test loss (mse, mae, mape) : (0.00676071, 0.06614195, 0.15811357)
#
# epoch 20 : time elapse 1.336
# train loss (mse, mae, mape) : (0.00327944, 0.03461405, 0.19079)
# test loss (mse, mae, mape) : (0.00660055, 0.06540824, 0.15611379)
#
# epoch 21 : time elapse 1.342
# train loss (mse, mae, mape) : (0.00316057, 0.03353583, 0.18482509)
# test loss (mse, mae, mape) : (0.0064912, 0.06499943, 0.15508091)
#
# epoch 22 : time elapse 1.33
# train loss (mse, mae, mape) : (0.00306487, 0.03268628, 0.18002132)
# test loss (mse, mae, mape) : (0.00641667, 0.06478121, 0.154582)
#
# epoch 23 : time elapse 1.35
# train loss (mse, mae, mape) : (0.003001, 0.03199396, 0.17631055)
# test loss (mse, mae, mape) : (0.00635502, 0.06462124, 0.15413338)
#
# epoch 24 : time elapse 1.349
# train loss (mse, mae, mape) : (0.00295953, 0.03149425, 0.17364122)
# test loss (mse, mae, mape) : (0.00629613, 0.06446762, 0.15356583)
#
# epoch 25 : time elapse 1.363
# train loss (mse, mae, mape) : (0.00290245, 0.03091983, 0.17018443)
# test loss (mse, mae, mape) : (0.00624697, 0.06438018, 0.15326098)
#
# epoch 26 : time elapse 1.347
# train loss (mse, mae, mape) : (0.00285822, 0.03049421, 0.16788477)
# test loss (mse, mae, mape) : (0.00620218, 0.06434676, 0.15352529)
#
# epoch 27 : time elapse 1.357
# train loss (mse, mae, mape) : (0.00284442, 0.03039593, 0.16799676)
# test loss (mse, mae, mape) : (0.00615815, 0.06433267, 0.15453311)
#
# epoch 28 : time elapse 1.316
# train loss (mse, mae, mape) : (0.00292109, 0.03093131, 0.17264736)
# test loss (mse, mae, mape) : (0.00611155, 0.06432931, 0.15634395)
#
# epoch 29 : time elapse 1.343
# train loss (mse, mae, mape) : (0.00316794, 0.03227543, 0.18266799)
# test loss (mse, mae, mape) : (0.00598533, 0.06373632, 0.15946136)
#
# epoch 30 : time elapse 1.329
# train loss (mse, mae, mape) : (0.00360695, 0.03450328, 0.19208231)
# test loss (mse, mae, mape) : (0.00568998, 0.06174495, 0.16690149)
#
# Trial Number - 30
# epoch 1 : time elapse 1.344
# train loss (mse, mae, mape) : (0.05810608, 0.13144244, 1.12696004)
# test loss (mse, mae, mape) : (0.00985577, 0.08223725, 0.16655226)
#
# epoch 2 : time elapse 1.346
# train loss (mse, mae, mape) : (0.01111268, 0.06156492, 0.37954708)
# test loss (mse, mae, mape) : (0.00686004, 0.06705389, 0.15572066)
#
# epoch 3 : time elapse 1.335
# train loss (mse, mae, mape) : (0.02135376, 0.08697495, 0.62708436)
# test loss (mse, mae, mape) : (0.00542065, 0.05840604, 0.16061596)
#
# epoch 4 : time elapse 1.361
# train loss (mse, mae, mape) : (0.00840242, 0.05533697, 0.40586619)
# test loss (mse, mae, mape) : (0.00518469, 0.0560746, 0.15909965)
#
# epoch 5 : time elapse 1.35
# train loss (mse, mae, mape) : (0.00488896, 0.04283863, 0.2879552)
# test loss (mse, mae, mape) : (0.0048664, 0.05410957, 0.15709695)
#
# epoch 6 : time elapse 1.339
# train loss (mse, mae, mape) : (0.0042747, 0.0400961, 0.2470122)
# test loss (mse, mae, mape) : (0.00466973, 0.05395171, 0.15347203)
#
# epoch 7 : time elapse 1.348
# train loss (mse, mae, mape) : (0.00437779, 0.04104448, 0.24638358)
# test loss (mse, mae, mape) : (0.00454315, 0.05371832, 0.1548859)
#
# epoch 8 : time elapse 1.349
# train loss (mse, mae, mape) : (0.00432714, 0.0390985, 0.21640117)
# test loss (mse, mae, mape) : (0.00405398, 0.05091029, 0.16513907)
#
# epoch 9 : time elapse 1.342
# train loss (mse, mae, mape) : (0.00417132, 0.0379153, 0.19822099)
# test loss (mse, mae, mape) : (0.00391685, 0.05006808, 0.17537049)
#
# epoch 10 : time elapse 1.36
# train loss (mse, mae, mape) : (0.0042785, 0.03810691, 0.2018021)
# test loss (mse, mae, mape) : (0.00394436, 0.0504106, 0.17687559)
#
# epoch 11 : time elapse 1.35
# train loss (mse, mae, mape) : (0.00567377, 0.04418193, 0.22621782)
# test loss (mse, mae, mape) : (0.00382649, 0.04958598, 0.16773723)
#
# epoch 12 : time elapse 1.346
# train loss (mse, mae, mape) : (0.00536453, 0.04172908, 0.20737854)
# test loss (mse, mae, mape) : (0.0037513, 0.04906746, 0.1626005)
#
# epoch 13 : time elapse 1.335
# train loss (mse, mae, mape) : (0.00430128, 0.03882143, 0.19957529)
# test loss (mse, mae, mape) : (0.00369672, 0.04868177, 0.16018857)
#
# epoch 14 : time elapse 1.36
# train loss (mse, mae, mape) : (0.0042593, 0.03786523, 0.19601705)
# test loss (mse, mae, mape) : (0.00371528, 0.04884182, 0.16032437)
#
# epoch 15 : time elapse 1.853
# train loss (mse, mae, mape) : (0.00390893, 0.03616295, 0.18678314)
# test loss (mse, mae, mape) : (0.00369855, 0.04869705, 0.16137697)
#
# epoch 16 : time elapse 2.15
# train loss (mse, mae, mape) : (0.00357636, 0.03396123, 0.17508554)
# test loss (mse, mae, mape) : (0.00366202, 0.04840073, 0.16371411)
#
# epoch 17 : time elapse 1.368
# train loss (mse, mae, mape) : (0.0033697, 0.03296693, 0.16858905)
# test loss (mse, mae, mape) : (0.00360449, 0.04784427, 0.16742907)
#
# epoch 18 : time elapse 1.338
# train loss (mse, mae, mape) : (0.00327947, 0.03254494, 0.1668643)
# test loss (mse, mae, mape) : (0.00354944, 0.04723671, 0.17273733)
#
# epoch 19 : time elapse 1.329
# train loss (mse, mae, mape) : (0.00318861, 0.03222591, 0.16707726)
# test loss (mse, mae, mape) : (0.00355503, 0.04713261, 0.17753139)
#
# epoch 20 : time elapse 1.349
# train loss (mse, mae, mape) : (0.00310981, 0.0320082, 0.16725864)
# test loss (mse, mae, mape) : (0.00359095, 0.04730447, 0.18092286)
#
# epoch 21 : time elapse 1.339
# train loss (mse, mae, mape) : (0.00308287, 0.03189964, 0.16840312)
# test loss (mse, mae, mape) : (0.00369359, 0.04795937, 0.18295455)
#
# epoch 22 : time elapse 1.349
# train loss (mse, mae, mape) : (0.0030821, 0.0318882, 0.16954359)
# test loss (mse, mae, mape) : (0.00385845, 0.04918447, 0.18128942)
#
# epoch 23 : time elapse 1.335
# train loss (mse, mae, mape) : (0.00303518, 0.03163333, 0.17031496)
# test loss (mse, mae, mape) : (0.00405211, 0.05069151, 0.17775532)
#
# epoch 24 : time elapse 1.334
# train loss (mse, mae, mape) : (0.00299374, 0.0315693, 0.17088015)
# test loss (mse, mae, mape) : (0.00428409, 0.05261788, 0.17406939)
#
# epoch 25 : time elapse 1.337
# train loss (mse, mae, mape) : (0.00299659, 0.03160626, 0.17156201)
# test loss (mse, mae, mape) : (0.00456406, 0.05498206, 0.17174283)
#
# epoch 26 : time elapse 1.341
# train loss (mse, mae, mape) : (0.00296534, 0.03145732, 0.17099186)
# test loss (mse, mae, mape) : (0.00475095, 0.05650319, 0.17044185)
#
# epoch 27 : time elapse 1.323
# train loss (mse, mae, mape) : (0.00295268, 0.03126609, 0.17017394)
# test loss (mse, mae, mape) : (0.00481409, 0.05701657, 0.16821359)
#
# epoch 28 : time elapse 1.348
# train loss (mse, mae, mape) : (0.00298736, 0.03144979, 0.17020874)
# test loss (mse, mae, mape) : (0.00478569, 0.0568142, 0.16401464)
#
# epoch 29 : time elapse 1.35
# train loss (mse, mae, mape) : (0.00305391, 0.03175428, 0.17081758)
# test loss (mse, mae, mape) : (0.00469913, 0.05606772, 0.15779013)
#
# epoch 30 : time elapse 1.332
# train loss (mse, mae, mape) : (0.00310301, 0.03192156, 0.17094088)
# test loss (mse, mae, mape) : (0.00469284, 0.05571434, 0.15195153)

# %%
# !pip install deepdish

import deepdish as dd
dd.io.save(f'weights_vanilla_lstm_{hidden_size}.h5', lib_weights)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: deepdish in /usr/local/lib/python3.8/dist-packages (0.3.7)
# Requirement already satisfied: tables in /usr/local/lib/python3.8/dist-packages (from deepdish) (3.7.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from deepdish) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from deepdish) (1.7.3)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.8/dist-packages (from tables->deepdish) (2.8.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tables->deepdish) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->tables->deepdish) (3.0.9)

# %%
load = dd.io.load(f'weights_vanilla_lstm_{hidden_size}.h5')

# %%
train_mse = []
train_mae = []
train_mape = []
test_mse = []
test_mae = []
test_mape = []
total_time = []

for key in load.keys():
    train_mse.append(load[key]['train_mse'])
    train_mae.append(load[key]['train_mae'])
    train_mape.append(load[key]['train_mape'])
    test_mse.append(load[key]['test_mse'])
    test_mae.append(load[key]['test_mae'])
    test_mape.append(load[key]['test_mape'])
    total_time.append(load[key]['total_time'])

print(f"train MSE \t: mean = {round(np.mean(train_mse), 5)},\t std = {round(np.std(train_mse), 5)}")
print(f"train MAE \t: mean = {round(np.mean(train_mae), 5)},\t std = {round(np.std(train_mae), 5)}")
print(f"train MAPE \t: mean = {round(np.mean(train_mape), 5)},\t std = {round(np.std(train_mape), 5)}")
print(f"test MSE \t: mean = {round(np.mean(test_mse), 5)},\t std = {round(np.std(test_mse), 5)}")
print(f"test MAE \t: mean = {round(np.mean(test_mae), 5)},\t std = {round(np.std(test_mae), 5)}")
print(f"test MAPE \t: mean = {round(np.mean(test_mape), 5)},\t std = {round(np.std(test_mape), 5)}")
print(f"total time \t: mean = {round(np.mean(total_time), 5)},\t std = {round(np.std(total_time), 5)}")
# Out:
# train MSE 	: mean = 0.00301,	 std = 0.00448
# train MAE 	: mean = 0.03064,	 std = 0.02253
# train MAPE 	: mean = 0.1651,	 std = 0.11433
# test MSE 	: mean = 0.00664,	 std = 0.01043
# test MAE 	: mean = 0.06137,	 std = 0.0278
# test MAPE 	: mean = 0.18711,	 std = 0.27158
# total time 	: mean = 40.46484,	 std = 0.51088
